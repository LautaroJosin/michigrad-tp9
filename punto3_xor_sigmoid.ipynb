# %%
from michigrad.engine import Value
from michigrad.nn_modified import MLP_Modified
from michigrad.nn_modified import Linear
from michigrad.nn_modified import Sigmoid
from michigrad.visualize import show_graph

# %%
# Datos para entrenar al modelo

# 4 arreglos con 2 Value cada uno 
Xs = [
    [Value(0.0), Value(0.0)],
    [Value(1.0), Value(0.0)],
    [Value(0.0), Value(1.0)],
    [Value(1.0), Value(1.0)],
]

Ys = [
    Value(0.0),
    Value(1.0),
    Value(1.0),
    Value(0.0),
]

# %% [markdown]
# # Entrenamiento del modelo con Sigmoide

# %%
# Entrenamiento del modelo

layer_1 = Linear(2,4)
layer_2 = Linear(4,1)
activation_function = Sigmoid()

model = MLP_Modified([
    layer_1,
    activation_function,
    layer_2,
    activation_function
])

N = len(Ys)
learning_rate = 1.0
L_sigmoid = Value(0)
yhat = []

for i in range(1000):
    
    # Forward pass
    yhat = [model(x) for x in Xs]

    # Calculo Loss function
    L_sigmoid = sum( (y - ypred)**2 for y, ypred in zip(Ys, yhat) ) * (Value(1) / Value(N))
    L_sigmoid.name = "L_sigmoid"
    
    # Gradiente en cero
    model.zero_grad()

    # Backpropagation
    L_sigmoid.backward()

    # Update
    for p in model.parameters():
        p.data -= learning_rate * p.grad

    print(f'Iteracion={i}, L_sigmoid={L_sigmoid.data:.5f}')
# Out:
# Iteracion=0, L_sigmoid=0.26128
# Iteracion=1, L_sigmoid=0.25612
# Iteracion=2, L_sigmoid=0.25311
# Iteracion=3, L_sigmoid=0.25142
# Iteracion=4, L_sigmoid=0.25048
# Iteracion=5, L_sigmoid=0.24996
# Iteracion=6, L_sigmoid=0.24968
# Iteracion=7, L_sigmoid=0.24951
# Iteracion=8, L_sigmoid=0.24942
# Iteracion=9, L_sigmoid=0.24936
# Iteracion=10, L_sigmoid=0.24932
# Iteracion=11, L_sigmoid=0.24930
# Iteracion=12, L_sigmoid=0.24927
# Iteracion=13, L_sigmoid=0.24925
# Iteracion=14, L_sigmoid=0.24924
# Iteracion=15, L_sigmoid=0.24922
# Iteracion=16, L_sigmoid=0.24920
# Iteracion=17, L_sigmoid=0.24918
# Iteracion=18, L_sigmoid=0.24917
# Iteracion=19, L_sigmoid=0.24915
# Iteracion=20, L_sigmoid=0.24913
# Iteracion=21, L_sigmoid=0.24912
# Iteracion=22, L_sigmoid=0.24910
# Iteracion=23, L_sigmoid=0.24908
# Iteracion=24, L_sigmoid=0.24906
# Iteracion=25, L_sigmoid=0.24905
# Iteracion=26, L_sigmoid=0.24903
# Iteracion=27, L_sigmoid=0.24901
# Iteracion=28, L_sigmoid=0.24899
# Iteracion=29, L_sigmoid=0.24897
# Iteracion=30, L_sigmoid=0.24896
# Iteracion=31, L_sigmoid=0.24894
# Iteracion=32, L_sigmoid=0.24892
# Iteracion=33, L_sigmoid=0.24890
# Iteracion=34, L_sigmoid=0.24888
# Iteracion=35, L_sigmoid=0.24886
# Iteracion=36, L_sigmoid=0.24884
# Iteracion=37, L_sigmoid=0.24882
# Iteracion=38, L_sigmoid=0.24880
# Iteracion=39, L_sigmoid=0.24878
# Iteracion=40, L_sigmoid=0.24876
# Iteracion=41, L_sigmoid=0.24874
# Iteracion=42, L_sigmoid=0.24872
# Iteracion=43, L_sigmoid=0.24870
# Iteracion=44, L_sigmoid=0.24868
# Iteracion=45, L_sigmoid=0.24866
# Iteracion=46, L_sigmoid=0.24864
# Iteracion=47, L_sigmoid=0.24862
# Iteracion=48, L_sigmoid=0.24860
# Iteracion=49, L_sigmoid=0.24857
# Iteracion=50, L_sigmoid=0.24855
# Iteracion=51, L_sigmoid=0.24853
# Iteracion=52, L_sigmoid=0.24851
# Iteracion=53, L_sigmoid=0.24848
# Iteracion=54, L_sigmoid=0.24846
# Iteracion=55, L_sigmoid=0.24844
# Iteracion=56, L_sigmoid=0.24841
# Iteracion=57, L_sigmoid=0.24839
# Iteracion=58, L_sigmoid=0.24837
# Iteracion=59, L_sigmoid=0.24834
# Iteracion=60, L_sigmoid=0.24832
# Iteracion=61, L_sigmoid=0.24829
# Iteracion=62, L_sigmoid=0.24827
# Iteracion=63, L_sigmoid=0.24824
# Iteracion=64, L_sigmoid=0.24822
# Iteracion=65, L_sigmoid=0.24819
# Iteracion=66, L_sigmoid=0.24816
# Iteracion=67, L_sigmoid=0.24814
# Iteracion=68, L_sigmoid=0.24811
# Iteracion=69, L_sigmoid=0.24808
# Iteracion=70, L_sigmoid=0.24805
# Iteracion=71, L_sigmoid=0.24803
# Iteracion=72, L_sigmoid=0.24800
# Iteracion=73, L_sigmoid=0.24797
# Iteracion=74, L_sigmoid=0.24794
# Iteracion=75, L_sigmoid=0.24791
# Iteracion=76, L_sigmoid=0.24788
# Iteracion=77, L_sigmoid=0.24785
# Iteracion=78, L_sigmoid=0.24782
# Iteracion=79, L_sigmoid=0.24779
# Iteracion=80, L_sigmoid=0.24776
# Iteracion=81, L_sigmoid=0.24772
# Iteracion=82, L_sigmoid=0.24769
# Iteracion=83, L_sigmoid=0.24766
# Iteracion=84, L_sigmoid=0.24763
# Iteracion=85, L_sigmoid=0.24759
# Iteracion=86, L_sigmoid=0.24756
# Iteracion=87, L_sigmoid=0.24752
# Iteracion=88, L_sigmoid=0.24749
# Iteracion=89, L_sigmoid=0.24745
# Iteracion=90, L_sigmoid=0.24742
# Iteracion=91, L_sigmoid=0.24738
# Iteracion=92, L_sigmoid=0.24734
# Iteracion=93, L_sigmoid=0.24731
# Iteracion=94, L_sigmoid=0.24727
# Iteracion=95, L_sigmoid=0.24723
# Iteracion=96, L_sigmoid=0.24719
# Iteracion=97, L_sigmoid=0.24715
# Iteracion=98, L_sigmoid=0.24711
# Iteracion=99, L_sigmoid=0.24707
# Iteracion=100, L_sigmoid=0.24703
# Iteracion=101, L_sigmoid=0.24698
# Iteracion=102, L_sigmoid=0.24694
# Iteracion=103, L_sigmoid=0.24690
# Iteracion=104, L_sigmoid=0.24685
# Iteracion=105, L_sigmoid=0.24681
# Iteracion=106, L_sigmoid=0.24677
# Iteracion=107, L_sigmoid=0.24672
# Iteracion=108, L_sigmoid=0.24667
# Iteracion=109, L_sigmoid=0.24663
# Iteracion=110, L_sigmoid=0.24658
# Iteracion=111, L_sigmoid=0.24653
# Iteracion=112, L_sigmoid=0.24648
# Iteracion=113, L_sigmoid=0.24643
# Iteracion=114, L_sigmoid=0.24638
# Iteracion=115, L_sigmoid=0.24633
# Iteracion=116, L_sigmoid=0.24627
# Iteracion=117, L_sigmoid=0.24622
# Iteracion=118, L_sigmoid=0.24617
# Iteracion=119, L_sigmoid=0.24611
# Iteracion=120, L_sigmoid=0.24606
# Iteracion=121, L_sigmoid=0.24600
# Iteracion=122, L_sigmoid=0.24594
# Iteracion=123, L_sigmoid=0.24589
# Iteracion=124, L_sigmoid=0.24583
# Iteracion=125, L_sigmoid=0.24577
# Iteracion=126, L_sigmoid=0.24571
# Iteracion=127, L_sigmoid=0.24564
# Iteracion=128, L_sigmoid=0.24558
# Iteracion=129, L_sigmoid=0.24552
# Iteracion=130, L_sigmoid=0.24545
# Iteracion=131, L_sigmoid=0.24539
# Iteracion=132, L_sigmoid=0.24532
# Iteracion=133, L_sigmoid=0.24525
# Iteracion=134, L_sigmoid=0.24518
# Iteracion=135, L_sigmoid=0.24511
# Iteracion=136, L_sigmoid=0.24504
# Iteracion=137, L_sigmoid=0.24497
# Iteracion=138, L_sigmoid=0.24490
# Iteracion=139, L_sigmoid=0.24482
# Iteracion=140, L_sigmoid=0.24475
# Iteracion=141, L_sigmoid=0.24467
# Iteracion=142, L_sigmoid=0.24459
# Iteracion=143, L_sigmoid=0.24451
# Iteracion=144, L_sigmoid=0.24443
# Iteracion=145, L_sigmoid=0.24435
# Iteracion=146, L_sigmoid=0.24427
# Iteracion=147, L_sigmoid=0.24418
# Iteracion=148, L_sigmoid=0.24410
# Iteracion=149, L_sigmoid=0.24401
# Iteracion=150, L_sigmoid=0.24392
# Iteracion=151, L_sigmoid=0.24383
# Iteracion=152, L_sigmoid=0.24374
# Iteracion=153, L_sigmoid=0.24365
# Iteracion=154, L_sigmoid=0.24355
# Iteracion=155, L_sigmoid=0.24346
# Iteracion=156, L_sigmoid=0.24336
# Iteracion=157, L_sigmoid=0.24326
# Iteracion=158, L_sigmoid=0.24316
# Iteracion=159, L_sigmoid=0.24306
# Iteracion=160, L_sigmoid=0.24296
# Iteracion=161, L_sigmoid=0.24285
# Iteracion=162, L_sigmoid=0.24274
# Iteracion=163, L_sigmoid=0.24263
# Iteracion=164, L_sigmoid=0.24252
# Iteracion=165, L_sigmoid=0.24241
# Iteracion=166, L_sigmoid=0.24230
# Iteracion=167, L_sigmoid=0.24218
# Iteracion=168, L_sigmoid=0.24206
# Iteracion=169, L_sigmoid=0.24194
# Iteracion=170, L_sigmoid=0.24182
# Iteracion=171, L_sigmoid=0.24170
# Iteracion=172, L_sigmoid=0.24157
# Iteracion=173, L_sigmoid=0.24145
# Iteracion=174, L_sigmoid=0.24132
# Iteracion=175, L_sigmoid=0.24118
# Iteracion=176, L_sigmoid=0.24105
# Iteracion=177, L_sigmoid=0.24091
# Iteracion=178, L_sigmoid=0.24078
# Iteracion=179, L_sigmoid=0.24064
# Iteracion=180, L_sigmoid=0.24049
# Iteracion=181, L_sigmoid=0.24035
# Iteracion=182, L_sigmoid=0.24020
# Iteracion=183, L_sigmoid=0.24005
# Iteracion=184, L_sigmoid=0.23990
# Iteracion=185, L_sigmoid=0.23974
# Iteracion=186, L_sigmoid=0.23959
# Iteracion=187, L_sigmoid=0.23943
# Iteracion=188, L_sigmoid=0.23926
# Iteracion=189, L_sigmoid=0.23910
# Iteracion=190, L_sigmoid=0.23893
# Iteracion=191, L_sigmoid=0.23876
# Iteracion=192, L_sigmoid=0.23859
# Iteracion=193, L_sigmoid=0.23841
# Iteracion=194, L_sigmoid=0.23823
# Iteracion=195, L_sigmoid=0.23805
# Iteracion=196, L_sigmoid=0.23787
# Iteracion=197, L_sigmoid=0.23768
# Iteracion=198, L_sigmoid=0.23749
# Iteracion=199, L_sigmoid=0.23730
# Iteracion=200, L_sigmoid=0.23710
# Iteracion=201, L_sigmoid=0.23690
# Iteracion=202, L_sigmoid=0.23670
# Iteracion=203, L_sigmoid=0.23649
# Iteracion=204, L_sigmoid=0.23628
# Iteracion=205, L_sigmoid=0.23607
# Iteracion=206, L_sigmoid=0.23586
# Iteracion=207, L_sigmoid=0.23564
# Iteracion=208, L_sigmoid=0.23541
# Iteracion=209, L_sigmoid=0.23519
# Iteracion=210, L_sigmoid=0.23496
# Iteracion=211, L_sigmoid=0.23473
# Iteracion=212, L_sigmoid=0.23449
# Iteracion=213, L_sigmoid=0.23425
# Iteracion=214, L_sigmoid=0.23400
# Iteracion=215, L_sigmoid=0.23376
# Iteracion=216, L_sigmoid=0.23350
# Iteracion=217, L_sigmoid=0.23325
# Iteracion=218, L_sigmoid=0.23299
# Iteracion=219, L_sigmoid=0.23272
# Iteracion=220, L_sigmoid=0.23246
# Iteracion=221, L_sigmoid=0.23219
# Iteracion=222, L_sigmoid=0.23191
# Iteracion=223, L_sigmoid=0.23163
# Iteracion=224, L_sigmoid=0.23134
# Iteracion=225, L_sigmoid=0.23106
# Iteracion=226, L_sigmoid=0.23076
# Iteracion=227, L_sigmoid=0.23046
# Iteracion=228, L_sigmoid=0.23016
# Iteracion=229, L_sigmoid=0.22986
# Iteracion=230, L_sigmoid=0.22954
# Iteracion=231, L_sigmoid=0.22923
# Iteracion=232, L_sigmoid=0.22891
# Iteracion=233, L_sigmoid=0.22858
# Iteracion=234, L_sigmoid=0.22825
# Iteracion=235, L_sigmoid=0.22792
# Iteracion=236, L_sigmoid=0.22758
# Iteracion=237, L_sigmoid=0.22723
# Iteracion=238, L_sigmoid=0.22688
# Iteracion=239, L_sigmoid=0.22653
# Iteracion=240, L_sigmoid=0.22617
# Iteracion=241, L_sigmoid=0.22580
# Iteracion=242, L_sigmoid=0.22543
# Iteracion=243, L_sigmoid=0.22506
# Iteracion=244, L_sigmoid=0.22468
# Iteracion=245, L_sigmoid=0.22429
# Iteracion=246, L_sigmoid=0.22390
# Iteracion=247, L_sigmoid=0.22350
# Iteracion=248, L_sigmoid=0.22310
# Iteracion=249, L_sigmoid=0.22269
# Iteracion=250, L_sigmoid=0.22227
# Iteracion=251, L_sigmoid=0.22185
# Iteracion=252, L_sigmoid=0.22143
# Iteracion=253, L_sigmoid=0.22100
# Iteracion=254, L_sigmoid=0.22056
# Iteracion=255, L_sigmoid=0.22012
# Iteracion=256, L_sigmoid=0.21967
# Iteracion=257, L_sigmoid=0.21921
# Iteracion=258, L_sigmoid=0.21875
# Iteracion=259, L_sigmoid=0.21828
# Iteracion=260, L_sigmoid=0.21781
# Iteracion=261, L_sigmoid=0.21733
# Iteracion=262, L_sigmoid=0.21684
# Iteracion=263, L_sigmoid=0.21635
# Iteracion=264, L_sigmoid=0.21585
# Iteracion=265, L_sigmoid=0.21534
# Iteracion=266, L_sigmoid=0.21483
# Iteracion=267, L_sigmoid=0.21431
# Iteracion=268, L_sigmoid=0.21379
# Iteracion=269, L_sigmoid=0.21326
# Iteracion=270, L_sigmoid=0.21272
# Iteracion=271, L_sigmoid=0.21217
# Iteracion=272, L_sigmoid=0.21162
# Iteracion=273, L_sigmoid=0.21106
# Iteracion=274, L_sigmoid=0.21050
# Iteracion=275, L_sigmoid=0.20993
# Iteracion=276, L_sigmoid=0.20935
# Iteracion=277, L_sigmoid=0.20876
# Iteracion=278, L_sigmoid=0.20817
# Iteracion=279, L_sigmoid=0.20757
# Iteracion=280, L_sigmoid=0.20696
# Iteracion=281, L_sigmoid=0.20635
# Iteracion=282, L_sigmoid=0.20573
# Iteracion=283, L_sigmoid=0.20510
# Iteracion=284, L_sigmoid=0.20447
# Iteracion=285, L_sigmoid=0.20382
# Iteracion=286, L_sigmoid=0.20317
# Iteracion=287, L_sigmoid=0.20252
# Iteracion=288, L_sigmoid=0.20185
# Iteracion=289, L_sigmoid=0.20118
# Iteracion=290, L_sigmoid=0.20050
# Iteracion=291, L_sigmoid=0.19982
# Iteracion=292, L_sigmoid=0.19913
# Iteracion=293, L_sigmoid=0.19843
# Iteracion=294, L_sigmoid=0.19772
# Iteracion=295, L_sigmoid=0.19700
# Iteracion=296, L_sigmoid=0.19628
# Iteracion=297, L_sigmoid=0.19555
# Iteracion=298, L_sigmoid=0.19482
# Iteracion=299, L_sigmoid=0.19407
# Iteracion=300, L_sigmoid=0.19332
# Iteracion=301, L_sigmoid=0.19256
# Iteracion=302, L_sigmoid=0.19180
# Iteracion=303, L_sigmoid=0.19102
# Iteracion=304, L_sigmoid=0.19024
# Iteracion=305, L_sigmoid=0.18946
# Iteracion=306, L_sigmoid=0.18866
# Iteracion=307, L_sigmoid=0.18786
# Iteracion=308, L_sigmoid=0.18705
# Iteracion=309, L_sigmoid=0.18624
# Iteracion=310, L_sigmoid=0.18541
# Iteracion=311, L_sigmoid=0.18458
# Iteracion=312, L_sigmoid=0.18375
# Iteracion=313, L_sigmoid=0.18290
# Iteracion=314, L_sigmoid=0.18205
# Iteracion=315, L_sigmoid=0.18119
# Iteracion=316, L_sigmoid=0.18033
# Iteracion=317, L_sigmoid=0.17946
# Iteracion=318, L_sigmoid=0.17858
# Iteracion=319, L_sigmoid=0.17770
# Iteracion=320, L_sigmoid=0.17680
# Iteracion=321, L_sigmoid=0.17591
# Iteracion=322, L_sigmoid=0.17500
# Iteracion=323, L_sigmoid=0.17409
# Iteracion=324, L_sigmoid=0.17318
# Iteracion=325, L_sigmoid=0.17226
# Iteracion=326, L_sigmoid=0.17133
# Iteracion=327, L_sigmoid=0.17039
# Iteracion=328, L_sigmoid=0.16945
# Iteracion=329, L_sigmoid=0.16851
# Iteracion=330, L_sigmoid=0.16756
# Iteracion=331, L_sigmoid=0.16660
# Iteracion=332, L_sigmoid=0.16564
# Iteracion=333, L_sigmoid=0.16467
# Iteracion=334, L_sigmoid=0.16370
# Iteracion=335, L_sigmoid=0.16272
# Iteracion=336, L_sigmoid=0.16174
# Iteracion=337, L_sigmoid=0.16076
# Iteracion=338, L_sigmoid=0.15977
# Iteracion=339, L_sigmoid=0.15877
# Iteracion=340, L_sigmoid=0.15777
# Iteracion=341, L_sigmoid=0.15677
# Iteracion=342, L_sigmoid=0.15576
# Iteracion=343, L_sigmoid=0.15475
# Iteracion=344, L_sigmoid=0.15374
# Iteracion=345, L_sigmoid=0.15272
# Iteracion=346, L_sigmoid=0.15170
# Iteracion=347, L_sigmoid=0.15068
# Iteracion=348, L_sigmoid=0.14965
# Iteracion=349, L_sigmoid=0.14862
# Iteracion=350, L_sigmoid=0.14759
# Iteracion=351, L_sigmoid=0.14656
# Iteracion=352, L_sigmoid=0.14552
# Iteracion=353, L_sigmoid=0.14449
# Iteracion=354, L_sigmoid=0.14345
# Iteracion=355, L_sigmoid=0.14241
# Iteracion=356, L_sigmoid=0.14137
# Iteracion=357, L_sigmoid=0.14032
# Iteracion=358, L_sigmoid=0.13928
# Iteracion=359, L_sigmoid=0.13824
# Iteracion=360, L_sigmoid=0.13719
# Iteracion=361, L_sigmoid=0.13615
# Iteracion=362, L_sigmoid=0.13511
# Iteracion=363, L_sigmoid=0.13406
# Iteracion=364, L_sigmoid=0.13302
# Iteracion=365, L_sigmoid=0.13198
# Iteracion=366, L_sigmoid=0.13094
# Iteracion=367, L_sigmoid=0.12990
# Iteracion=368, L_sigmoid=0.12886
# Iteracion=369, L_sigmoid=0.12782
# Iteracion=370, L_sigmoid=0.12679
# Iteracion=371, L_sigmoid=0.12575
# Iteracion=372, L_sigmoid=0.12472
# Iteracion=373, L_sigmoid=0.12369
# Iteracion=374, L_sigmoid=0.12267
# Iteracion=375, L_sigmoid=0.12164
# Iteracion=376, L_sigmoid=0.12062
# Iteracion=377, L_sigmoid=0.11960
# Iteracion=378, L_sigmoid=0.11859
# Iteracion=379, L_sigmoid=0.11758
# Iteracion=380, L_sigmoid=0.11657
# Iteracion=381, L_sigmoid=0.11557
# Iteracion=382, L_sigmoid=0.11457
# Iteracion=383, L_sigmoid=0.11357
# Iteracion=384, L_sigmoid=0.11258
# Iteracion=385, L_sigmoid=0.11160
# Iteracion=386, L_sigmoid=0.11062
# Iteracion=387, L_sigmoid=0.10964
# Iteracion=388, L_sigmoid=0.10867
# Iteracion=389, L_sigmoid=0.10770
# Iteracion=390, L_sigmoid=0.10674
# Iteracion=391, L_sigmoid=0.10578
# Iteracion=392, L_sigmoid=0.10483
# Iteracion=393, L_sigmoid=0.10389
# Iteracion=394, L_sigmoid=0.10295
# Iteracion=395, L_sigmoid=0.10201
# Iteracion=396, L_sigmoid=0.10109
# Iteracion=397, L_sigmoid=0.10017
# Iteracion=398, L_sigmoid=0.09925
# Iteracion=399, L_sigmoid=0.09834
# Iteracion=400, L_sigmoid=0.09744
# Iteracion=401, L_sigmoid=0.09654
# Iteracion=402, L_sigmoid=0.09565
# Iteracion=403, L_sigmoid=0.09477
# Iteracion=404, L_sigmoid=0.09390
# Iteracion=405, L_sigmoid=0.09303
# Iteracion=406, L_sigmoid=0.09216
# Iteracion=407, L_sigmoid=0.09131
# Iteracion=408, L_sigmoid=0.09046
# Iteracion=409, L_sigmoid=0.08962
# Iteracion=410, L_sigmoid=0.08878
# Iteracion=411, L_sigmoid=0.08795
# Iteracion=412, L_sigmoid=0.08713
# Iteracion=413, L_sigmoid=0.08632
# Iteracion=414, L_sigmoid=0.08551
# Iteracion=415, L_sigmoid=0.08471
# Iteracion=416, L_sigmoid=0.08392
# Iteracion=417, L_sigmoid=0.08314
# Iteracion=418, L_sigmoid=0.08236
# Iteracion=419, L_sigmoid=0.08159
# Iteracion=420, L_sigmoid=0.08083
# Iteracion=421, L_sigmoid=0.08007
# Iteracion=422, L_sigmoid=0.07932
# Iteracion=423, L_sigmoid=0.07858
# Iteracion=424, L_sigmoid=0.07785
# Iteracion=425, L_sigmoid=0.07712
# Iteracion=426, L_sigmoid=0.07640
# Iteracion=427, L_sigmoid=0.07569
# Iteracion=428, L_sigmoid=0.07499
# Iteracion=429, L_sigmoid=0.07429
# Iteracion=430, L_sigmoid=0.07360
# Iteracion=431, L_sigmoid=0.07291
# Iteracion=432, L_sigmoid=0.07224
# Iteracion=433, L_sigmoid=0.07157
# Iteracion=434, L_sigmoid=0.07090
# Iteracion=435, L_sigmoid=0.07025
# Iteracion=436, L_sigmoid=0.06960
# Iteracion=437, L_sigmoid=0.06896
# Iteracion=438, L_sigmoid=0.06832
# Iteracion=439, L_sigmoid=0.06770
# Iteracion=440, L_sigmoid=0.06708
# Iteracion=441, L_sigmoid=0.06646
# Iteracion=442, L_sigmoid=0.06585
# Iteracion=443, L_sigmoid=0.06525
# Iteracion=444, L_sigmoid=0.06466
# Iteracion=445, L_sigmoid=0.06407
# Iteracion=446, L_sigmoid=0.06349
# Iteracion=447, L_sigmoid=0.06292
# Iteracion=448, L_sigmoid=0.06235
# Iteracion=449, L_sigmoid=0.06179
# Iteracion=450, L_sigmoid=0.06123
# Iteracion=451, L_sigmoid=0.06068
# Iteracion=452, L_sigmoid=0.06014
# Iteracion=453, L_sigmoid=0.05960
# Iteracion=454, L_sigmoid=0.05907
# Iteracion=455, L_sigmoid=0.05855
# Iteracion=456, L_sigmoid=0.05803
# Iteracion=457, L_sigmoid=0.05751
# Iteracion=458, L_sigmoid=0.05701
# Iteracion=459, L_sigmoid=0.05651
# Iteracion=460, L_sigmoid=0.05601
# Iteracion=461, L_sigmoid=0.05552
# Iteracion=462, L_sigmoid=0.05504
# Iteracion=463, L_sigmoid=0.05456
# Iteracion=464, L_sigmoid=0.05409
# Iteracion=465, L_sigmoid=0.05362
# Iteracion=466, L_sigmoid=0.05316
# Iteracion=467, L_sigmoid=0.05270
# Iteracion=468, L_sigmoid=0.05225
# Iteracion=469, L_sigmoid=0.05180
# Iteracion=470, L_sigmoid=0.05136
# Iteracion=471, L_sigmoid=0.05092
# Iteracion=472, L_sigmoid=0.05049
# Iteracion=473, L_sigmoid=0.05007
# Iteracion=474, L_sigmoid=0.04965
# Iteracion=475, L_sigmoid=0.04923
# Iteracion=476, L_sigmoid=0.04882
# Iteracion=477, L_sigmoid=0.04841
# Iteracion=478, L_sigmoid=0.04801
# Iteracion=479, L_sigmoid=0.04761
# Iteracion=480, L_sigmoid=0.04722
# Iteracion=481, L_sigmoid=0.04683
# Iteracion=482, L_sigmoid=0.04645
# Iteracion=483, L_sigmoid=0.04607
# Iteracion=484, L_sigmoid=0.04569
# Iteracion=485, L_sigmoid=0.04532
# Iteracion=486, L_sigmoid=0.04496
# Iteracion=487, L_sigmoid=0.04459
# Iteracion=488, L_sigmoid=0.04424
# Iteracion=489, L_sigmoid=0.04388
# Iteracion=490, L_sigmoid=0.04353
# Iteracion=491, L_sigmoid=0.04319
# Iteracion=492, L_sigmoid=0.04285
# Iteracion=493, L_sigmoid=0.04251
# Iteracion=494, L_sigmoid=0.04217
# Iteracion=495, L_sigmoid=0.04184
# Iteracion=496, L_sigmoid=0.04152
# Iteracion=497, L_sigmoid=0.04119
# Iteracion=498, L_sigmoid=0.04087
# Iteracion=499, L_sigmoid=0.04056
# Iteracion=500, L_sigmoid=0.04025
# Iteracion=501, L_sigmoid=0.03994
# Iteracion=502, L_sigmoid=0.03963
# Iteracion=503, L_sigmoid=0.03933
# Iteracion=504, L_sigmoid=0.03903
# Iteracion=505, L_sigmoid=0.03874
# Iteracion=506, L_sigmoid=0.03845
# Iteracion=507, L_sigmoid=0.03816
# Iteracion=508, L_sigmoid=0.03788
# Iteracion=509, L_sigmoid=0.03759
# Iteracion=510, L_sigmoid=0.03731
# Iteracion=511, L_sigmoid=0.03704
# Iteracion=512, L_sigmoid=0.03677
# Iteracion=513, L_sigmoid=0.03650
# Iteracion=514, L_sigmoid=0.03623
# Iteracion=515, L_sigmoid=0.03597
# Iteracion=516, L_sigmoid=0.03571
# Iteracion=517, L_sigmoid=0.03545
# Iteracion=518, L_sigmoid=0.03519
# Iteracion=519, L_sigmoid=0.03494
# Iteracion=520, L_sigmoid=0.03469
# Iteracion=521, L_sigmoid=0.03445
# Iteracion=522, L_sigmoid=0.03420
# Iteracion=523, L_sigmoid=0.03396
# Iteracion=524, L_sigmoid=0.03372
# Iteracion=525, L_sigmoid=0.03348
# Iteracion=526, L_sigmoid=0.03325
# Iteracion=527, L_sigmoid=0.03302
# Iteracion=528, L_sigmoid=0.03279
# Iteracion=529, L_sigmoid=0.03256
# Iteracion=530, L_sigmoid=0.03234
# Iteracion=531, L_sigmoid=0.03212
# Iteracion=532, L_sigmoid=0.03190
# Iteracion=533, L_sigmoid=0.03168
# Iteracion=534, L_sigmoid=0.03147
# Iteracion=535, L_sigmoid=0.03126
# Iteracion=536, L_sigmoid=0.03105
# Iteracion=537, L_sigmoid=0.03084
# Iteracion=538, L_sigmoid=0.03063
# Iteracion=539, L_sigmoid=0.03043
# Iteracion=540, L_sigmoid=0.03023
# Iteracion=541, L_sigmoid=0.03003
# Iteracion=542, L_sigmoid=0.02983
# Iteracion=543, L_sigmoid=0.02964
# Iteracion=544, L_sigmoid=0.02944
# Iteracion=545, L_sigmoid=0.02925
# Iteracion=546, L_sigmoid=0.02906
# Iteracion=547, L_sigmoid=0.02887
# Iteracion=548, L_sigmoid=0.02869
# Iteracion=549, L_sigmoid=0.02851
# Iteracion=550, L_sigmoid=0.02832
# Iteracion=551, L_sigmoid=0.02814
# Iteracion=552, L_sigmoid=0.02797
# Iteracion=553, L_sigmoid=0.02779
# Iteracion=554, L_sigmoid=0.02761
# Iteracion=555, L_sigmoid=0.02744
# Iteracion=556, L_sigmoid=0.02727
# Iteracion=557, L_sigmoid=0.02710
# Iteracion=558, L_sigmoid=0.02693
# Iteracion=559, L_sigmoid=0.02677
# Iteracion=560, L_sigmoid=0.02660
# Iteracion=561, L_sigmoid=0.02644
# Iteracion=562, L_sigmoid=0.02628
# Iteracion=563, L_sigmoid=0.02612
# Iteracion=564, L_sigmoid=0.02596
# Iteracion=565, L_sigmoid=0.02580
# Iteracion=566, L_sigmoid=0.02565
# Iteracion=567, L_sigmoid=0.02550
# Iteracion=568, L_sigmoid=0.02534
# Iteracion=569, L_sigmoid=0.02519
# Iteracion=570, L_sigmoid=0.02504
# Iteracion=571, L_sigmoid=0.02490
# Iteracion=572, L_sigmoid=0.02475
# Iteracion=573, L_sigmoid=0.02461
# Iteracion=574, L_sigmoid=0.02446
# Iteracion=575, L_sigmoid=0.02432
# Iteracion=576, L_sigmoid=0.02418
# Iteracion=577, L_sigmoid=0.02404
# Iteracion=578, L_sigmoid=0.02390
# Iteracion=579, L_sigmoid=0.02376
# Iteracion=580, L_sigmoid=0.02363
# Iteracion=581, L_sigmoid=0.02349
# Iteracion=582, L_sigmoid=0.02336
# Iteracion=583, L_sigmoid=0.02323
# Iteracion=584, L_sigmoid=0.02310
# Iteracion=585, L_sigmoid=0.02297
# Iteracion=586, L_sigmoid=0.02284
# Iteracion=587, L_sigmoid=0.02271
# Iteracion=588, L_sigmoid=0.02259
# Iteracion=589, L_sigmoid=0.02246
# Iteracion=590, L_sigmoid=0.02234
# Iteracion=591, L_sigmoid=0.02222
# Iteracion=592, L_sigmoid=0.02209
# Iteracion=593, L_sigmoid=0.02197
# Iteracion=594, L_sigmoid=0.02185
# Iteracion=595, L_sigmoid=0.02174
# Iteracion=596, L_sigmoid=0.02162
# Iteracion=597, L_sigmoid=0.02150
# Iteracion=598, L_sigmoid=0.02139
# Iteracion=599, L_sigmoid=0.02127
# Iteracion=600, L_sigmoid=0.02116
# Iteracion=601, L_sigmoid=0.02105
# Iteracion=602, L_sigmoid=0.02094
# Iteracion=603, L_sigmoid=0.02083
# Iteracion=604, L_sigmoid=0.02072
# Iteracion=605, L_sigmoid=0.02061
# Iteracion=606, L_sigmoid=0.02050
# Iteracion=607, L_sigmoid=0.02040
# Iteracion=608, L_sigmoid=0.02029
# Iteracion=609, L_sigmoid=0.02019
# Iteracion=610, L_sigmoid=0.02008
# Iteracion=611, L_sigmoid=0.01998
# Iteracion=612, L_sigmoid=0.01988
# Iteracion=613, L_sigmoid=0.01978
# Iteracion=614, L_sigmoid=0.01968
# Iteracion=615, L_sigmoid=0.01958
# Iteracion=616, L_sigmoid=0.01948
# Iteracion=617, L_sigmoid=0.01938
# Iteracion=618, L_sigmoid=0.01928
# Iteracion=619, L_sigmoid=0.01919
# Iteracion=620, L_sigmoid=0.01909
# Iteracion=621, L_sigmoid=0.01900
# Iteracion=622, L_sigmoid=0.01890
# Iteracion=623, L_sigmoid=0.01881
# Iteracion=624, L_sigmoid=0.01872
# Iteracion=625, L_sigmoid=0.01863
# Iteracion=626, L_sigmoid=0.01854
# Iteracion=627, L_sigmoid=0.01845
# Iteracion=628, L_sigmoid=0.01836
# Iteracion=629, L_sigmoid=0.01827
# Iteracion=630, L_sigmoid=0.01818
# Iteracion=631, L_sigmoid=0.01809
# Iteracion=632, L_sigmoid=0.01801
# Iteracion=633, L_sigmoid=0.01792
# Iteracion=634, L_sigmoid=0.01784
# Iteracion=635, L_sigmoid=0.01775
# Iteracion=636, L_sigmoid=0.01767
# Iteracion=637, L_sigmoid=0.01759
# Iteracion=638, L_sigmoid=0.01750
# Iteracion=639, L_sigmoid=0.01742
# Iteracion=640, L_sigmoid=0.01734
# Iteracion=641, L_sigmoid=0.01726
# Iteracion=642, L_sigmoid=0.01718
# Iteracion=643, L_sigmoid=0.01710
# Iteracion=644, L_sigmoid=0.01702
# Iteracion=645, L_sigmoid=0.01694
# Iteracion=646, L_sigmoid=0.01687
# Iteracion=647, L_sigmoid=0.01679
# Iteracion=648, L_sigmoid=0.01671
# Iteracion=649, L_sigmoid=0.01664
# Iteracion=650, L_sigmoid=0.01656
# Iteracion=651, L_sigmoid=0.01649
# Iteracion=652, L_sigmoid=0.01642
# Iteracion=653, L_sigmoid=0.01634
# Iteracion=654, L_sigmoid=0.01627
# Iteracion=655, L_sigmoid=0.01620
# Iteracion=656, L_sigmoid=0.01613
# Iteracion=657, L_sigmoid=0.01606
# Iteracion=658, L_sigmoid=0.01598
# Iteracion=659, L_sigmoid=0.01591
# Iteracion=660, L_sigmoid=0.01585
# Iteracion=661, L_sigmoid=0.01578
# Iteracion=662, L_sigmoid=0.01571
# Iteracion=663, L_sigmoid=0.01564
# Iteracion=664, L_sigmoid=0.01557
# Iteracion=665, L_sigmoid=0.01551
# Iteracion=666, L_sigmoid=0.01544
# Iteracion=667, L_sigmoid=0.01537
# Iteracion=668, L_sigmoid=0.01531
# Iteracion=669, L_sigmoid=0.01524
# Iteracion=670, L_sigmoid=0.01518
# Iteracion=671, L_sigmoid=0.01511
# Iteracion=672, L_sigmoid=0.01505
# Iteracion=673, L_sigmoid=0.01499
# Iteracion=674, L_sigmoid=0.01492
# Iteracion=675, L_sigmoid=0.01486
# Iteracion=676, L_sigmoid=0.01480
# Iteracion=677, L_sigmoid=0.01474
# Iteracion=678, L_sigmoid=0.01468
# Iteracion=679, L_sigmoid=0.01462
# Iteracion=680, L_sigmoid=0.01456
# Iteracion=681, L_sigmoid=0.01450
# Iteracion=682, L_sigmoid=0.01444
# Iteracion=683, L_sigmoid=0.01438
# Iteracion=684, L_sigmoid=0.01432
# Iteracion=685, L_sigmoid=0.01426
# Iteracion=686, L_sigmoid=0.01421
# Iteracion=687, L_sigmoid=0.01415
# Iteracion=688, L_sigmoid=0.01409
# Iteracion=689, L_sigmoid=0.01403
# Iteracion=690, L_sigmoid=0.01398
# Iteracion=691, L_sigmoid=0.01392
# Iteracion=692, L_sigmoid=0.01387
# Iteracion=693, L_sigmoid=0.01381
# Iteracion=694, L_sigmoid=0.01376
# Iteracion=695, L_sigmoid=0.01370
# Iteracion=696, L_sigmoid=0.01365
# Iteracion=697, L_sigmoid=0.01360
# Iteracion=698, L_sigmoid=0.01354
# Iteracion=699, L_sigmoid=0.01349
# Iteracion=700, L_sigmoid=0.01344
# Iteracion=701, L_sigmoid=0.01339
# Iteracion=702, L_sigmoid=0.01334
# Iteracion=703, L_sigmoid=0.01328
# Iteracion=704, L_sigmoid=0.01323
# Iteracion=705, L_sigmoid=0.01318
# Iteracion=706, L_sigmoid=0.01313
# Iteracion=707, L_sigmoid=0.01308
# Iteracion=708, L_sigmoid=0.01303
# Iteracion=709, L_sigmoid=0.01298
# Iteracion=710, L_sigmoid=0.01293
# Iteracion=711, L_sigmoid=0.01289
# Iteracion=712, L_sigmoid=0.01284
# Iteracion=713, L_sigmoid=0.01279
# Iteracion=714, L_sigmoid=0.01274
# Iteracion=715, L_sigmoid=0.01269
# Iteracion=716, L_sigmoid=0.01265
# Iteracion=717, L_sigmoid=0.01260
# Iteracion=718, L_sigmoid=0.01255
# Iteracion=719, L_sigmoid=0.01251
# Iteracion=720, L_sigmoid=0.01246
# Iteracion=721, L_sigmoid=0.01242
# Iteracion=722, L_sigmoid=0.01237
# Iteracion=723, L_sigmoid=0.01233
# Iteracion=724, L_sigmoid=0.01228
# Iteracion=725, L_sigmoid=0.01224
# Iteracion=726, L_sigmoid=0.01219
# Iteracion=727, L_sigmoid=0.01215
# Iteracion=728, L_sigmoid=0.01210
# Iteracion=729, L_sigmoid=0.01206
# Iteracion=730, L_sigmoid=0.01202
# Iteracion=731, L_sigmoid=0.01198
# Iteracion=732, L_sigmoid=0.01193
# Iteracion=733, L_sigmoid=0.01189
# Iteracion=734, L_sigmoid=0.01185
# Iteracion=735, L_sigmoid=0.01181
# Iteracion=736, L_sigmoid=0.01177
# Iteracion=737, L_sigmoid=0.01172
# Iteracion=738, L_sigmoid=0.01168
# Iteracion=739, L_sigmoid=0.01164
# Iteracion=740, L_sigmoid=0.01160
# Iteracion=741, L_sigmoid=0.01156
# Iteracion=742, L_sigmoid=0.01152
# Iteracion=743, L_sigmoid=0.01148
# Iteracion=744, L_sigmoid=0.01144
# Iteracion=745, L_sigmoid=0.01140
# Iteracion=746, L_sigmoid=0.01136
# Iteracion=747, L_sigmoid=0.01133
# Iteracion=748, L_sigmoid=0.01129
# Iteracion=749, L_sigmoid=0.01125
# Iteracion=750, L_sigmoid=0.01121
# Iteracion=751, L_sigmoid=0.01117
# Iteracion=752, L_sigmoid=0.01113
# Iteracion=753, L_sigmoid=0.01110
# Iteracion=754, L_sigmoid=0.01106
# Iteracion=755, L_sigmoid=0.01102
# Iteracion=756, L_sigmoid=0.01099
# Iteracion=757, L_sigmoid=0.01095
# Iteracion=758, L_sigmoid=0.01091
# Iteracion=759, L_sigmoid=0.01088
# Iteracion=760, L_sigmoid=0.01084
# Iteracion=761, L_sigmoid=0.01080
# Iteracion=762, L_sigmoid=0.01077
# Iteracion=763, L_sigmoid=0.01073
# Iteracion=764, L_sigmoid=0.01070
# Iteracion=765, L_sigmoid=0.01066
# Iteracion=766, L_sigmoid=0.01063
# Iteracion=767, L_sigmoid=0.01059
# Iteracion=768, L_sigmoid=0.01056
# Iteracion=769, L_sigmoid=0.01053
# Iteracion=770, L_sigmoid=0.01049
# Iteracion=771, L_sigmoid=0.01046
# Iteracion=772, L_sigmoid=0.01042
# Iteracion=773, L_sigmoid=0.01039
# Iteracion=774, L_sigmoid=0.01036
# Iteracion=775, L_sigmoid=0.01033
# Iteracion=776, L_sigmoid=0.01029
# Iteracion=777, L_sigmoid=0.01026
# Iteracion=778, L_sigmoid=0.01023
# Iteracion=779, L_sigmoid=0.01020
# Iteracion=780, L_sigmoid=0.01016
# Iteracion=781, L_sigmoid=0.01013
# Iteracion=782, L_sigmoid=0.01010
# Iteracion=783, L_sigmoid=0.01007
# Iteracion=784, L_sigmoid=0.01004
# Iteracion=785, L_sigmoid=0.01001
# Iteracion=786, L_sigmoid=0.00997
# Iteracion=787, L_sigmoid=0.00994
# Iteracion=788, L_sigmoid=0.00991
# Iteracion=789, L_sigmoid=0.00988
# Iteracion=790, L_sigmoid=0.00985
# Iteracion=791, L_sigmoid=0.00982
# Iteracion=792, L_sigmoid=0.00979
# Iteracion=793, L_sigmoid=0.00976
# Iteracion=794, L_sigmoid=0.00973
# Iteracion=795, L_sigmoid=0.00970
# Iteracion=796, L_sigmoid=0.00967
# Iteracion=797, L_sigmoid=0.00964
# Iteracion=798, L_sigmoid=0.00961
# Iteracion=799, L_sigmoid=0.00959
# Iteracion=800, L_sigmoid=0.00956
# Iteracion=801, L_sigmoid=0.00953
# Iteracion=802, L_sigmoid=0.00950
# Iteracion=803, L_sigmoid=0.00947
# Iteracion=804, L_sigmoid=0.00944
# Iteracion=805, L_sigmoid=0.00942
# Iteracion=806, L_sigmoid=0.00939
# Iteracion=807, L_sigmoid=0.00936
# Iteracion=808, L_sigmoid=0.00933
# Iteracion=809, L_sigmoid=0.00930
# Iteracion=810, L_sigmoid=0.00928
# Iteracion=811, L_sigmoid=0.00925
# Iteracion=812, L_sigmoid=0.00922
# Iteracion=813, L_sigmoid=0.00920
# Iteracion=814, L_sigmoid=0.00917
# Iteracion=815, L_sigmoid=0.00914
# Iteracion=816, L_sigmoid=0.00912
# Iteracion=817, L_sigmoid=0.00909
# Iteracion=818, L_sigmoid=0.00906
# Iteracion=819, L_sigmoid=0.00904
# Iteracion=820, L_sigmoid=0.00901
# Iteracion=821, L_sigmoid=0.00899
# Iteracion=822, L_sigmoid=0.00896
# Iteracion=823, L_sigmoid=0.00893
# Iteracion=824, L_sigmoid=0.00891
# Iteracion=825, L_sigmoid=0.00888
# Iteracion=826, L_sigmoid=0.00886
# Iteracion=827, L_sigmoid=0.00883
# Iteracion=828, L_sigmoid=0.00881
# Iteracion=829, L_sigmoid=0.00878
# Iteracion=830, L_sigmoid=0.00876
# Iteracion=831, L_sigmoid=0.00873
# Iteracion=832, L_sigmoid=0.00871
# Iteracion=833, L_sigmoid=0.00869
# Iteracion=834, L_sigmoid=0.00866
# Iteracion=835, L_sigmoid=0.00864
# Iteracion=836, L_sigmoid=0.00861
# Iteracion=837, L_sigmoid=0.00859
# Iteracion=838, L_sigmoid=0.00857
# Iteracion=839, L_sigmoid=0.00854
# Iteracion=840, L_sigmoid=0.00852
# Iteracion=841, L_sigmoid=0.00850
# Iteracion=842, L_sigmoid=0.00847
# Iteracion=843, L_sigmoid=0.00845
# Iteracion=844, L_sigmoid=0.00843
# Iteracion=845, L_sigmoid=0.00840
# Iteracion=846, L_sigmoid=0.00838
# Iteracion=847, L_sigmoid=0.00836
# Iteracion=848, L_sigmoid=0.00834
# Iteracion=849, L_sigmoid=0.00831
# Iteracion=850, L_sigmoid=0.00829
# Iteracion=851, L_sigmoid=0.00827
# Iteracion=852, L_sigmoid=0.00825
# Iteracion=853, L_sigmoid=0.00822
# Iteracion=854, L_sigmoid=0.00820
# Iteracion=855, L_sigmoid=0.00818
# Iteracion=856, L_sigmoid=0.00816
# Iteracion=857, L_sigmoid=0.00814
# Iteracion=858, L_sigmoid=0.00812
# Iteracion=859, L_sigmoid=0.00809
# Iteracion=860, L_sigmoid=0.00807
# Iteracion=861, L_sigmoid=0.00805
# Iteracion=862, L_sigmoid=0.00803
# Iteracion=863, L_sigmoid=0.00801
# Iteracion=864, L_sigmoid=0.00799
# Iteracion=865, L_sigmoid=0.00797
# Iteracion=866, L_sigmoid=0.00795
# Iteracion=867, L_sigmoid=0.00793
# Iteracion=868, L_sigmoid=0.00791
# Iteracion=869, L_sigmoid=0.00789
# Iteracion=870, L_sigmoid=0.00787
# Iteracion=871, L_sigmoid=0.00785
# Iteracion=872, L_sigmoid=0.00783
# Iteracion=873, L_sigmoid=0.00781
# Iteracion=874, L_sigmoid=0.00779
# Iteracion=875, L_sigmoid=0.00777
# Iteracion=876, L_sigmoid=0.00775
# Iteracion=877, L_sigmoid=0.00773
# Iteracion=878, L_sigmoid=0.00771
# Iteracion=879, L_sigmoid=0.00769
# Iteracion=880, L_sigmoid=0.00767
# Iteracion=881, L_sigmoid=0.00765
# Iteracion=882, L_sigmoid=0.00763
# Iteracion=883, L_sigmoid=0.00761
# Iteracion=884, L_sigmoid=0.00759
# Iteracion=885, L_sigmoid=0.00757
# Iteracion=886, L_sigmoid=0.00755
# Iteracion=887, L_sigmoid=0.00753
# Iteracion=888, L_sigmoid=0.00751
# Iteracion=889, L_sigmoid=0.00750
# Iteracion=890, L_sigmoid=0.00748
# Iteracion=891, L_sigmoid=0.00746
# Iteracion=892, L_sigmoid=0.00744
# Iteracion=893, L_sigmoid=0.00742
# Iteracion=894, L_sigmoid=0.00740
# Iteracion=895, L_sigmoid=0.00739
# Iteracion=896, L_sigmoid=0.00737
# Iteracion=897, L_sigmoid=0.00735
# Iteracion=898, L_sigmoid=0.00733
# Iteracion=899, L_sigmoid=0.00731
# Iteracion=900, L_sigmoid=0.00730
# Iteracion=901, L_sigmoid=0.00728
# Iteracion=902, L_sigmoid=0.00726
# Iteracion=903, L_sigmoid=0.00724
# Iteracion=904, L_sigmoid=0.00723
# Iteracion=905, L_sigmoid=0.00721
# Iteracion=906, L_sigmoid=0.00719
# Iteracion=907, L_sigmoid=0.00717
# Iteracion=908, L_sigmoid=0.00716
# Iteracion=909, L_sigmoid=0.00714
# Iteracion=910, L_sigmoid=0.00712
# Iteracion=911, L_sigmoid=0.00711
# Iteracion=912, L_sigmoid=0.00709
# Iteracion=913, L_sigmoid=0.00707
# Iteracion=914, L_sigmoid=0.00706
# Iteracion=915, L_sigmoid=0.00704
# Iteracion=916, L_sigmoid=0.00702
# Iteracion=917, L_sigmoid=0.00701
# Iteracion=918, L_sigmoid=0.00699
# Iteracion=919, L_sigmoid=0.00697
# Iteracion=920, L_sigmoid=0.00696
# Iteracion=921, L_sigmoid=0.00694
# Iteracion=922, L_sigmoid=0.00692
# Iteracion=923, L_sigmoid=0.00691
# Iteracion=924, L_sigmoid=0.00689
# Iteracion=925, L_sigmoid=0.00688
# Iteracion=926, L_sigmoid=0.00686
# Iteracion=927, L_sigmoid=0.00684
# Iteracion=928, L_sigmoid=0.00683
# Iteracion=929, L_sigmoid=0.00681
# Iteracion=930, L_sigmoid=0.00680
# Iteracion=931, L_sigmoid=0.00678
# Iteracion=932, L_sigmoid=0.00677
# Iteracion=933, L_sigmoid=0.00675
# Iteracion=934, L_sigmoid=0.00674
# Iteracion=935, L_sigmoid=0.00672
# Iteracion=936, L_sigmoid=0.00670
# Iteracion=937, L_sigmoid=0.00669
# Iteracion=938, L_sigmoid=0.00667
# Iteracion=939, L_sigmoid=0.00666
# Iteracion=940, L_sigmoid=0.00664
# Iteracion=941, L_sigmoid=0.00663
# Iteracion=942, L_sigmoid=0.00661
# Iteracion=943, L_sigmoid=0.00660
# Iteracion=944, L_sigmoid=0.00658
# Iteracion=945, L_sigmoid=0.00657
# Iteracion=946, L_sigmoid=0.00656
# Iteracion=947, L_sigmoid=0.00654
# Iteracion=948, L_sigmoid=0.00653
# Iteracion=949, L_sigmoid=0.00651
# Iteracion=950, L_sigmoid=0.00650
# Iteracion=951, L_sigmoid=0.00648
# Iteracion=952, L_sigmoid=0.00647
# Iteracion=953, L_sigmoid=0.00645
# Iteracion=954, L_sigmoid=0.00644
# Iteracion=955, L_sigmoid=0.00643
# Iteracion=956, L_sigmoid=0.00641
# Iteracion=957, L_sigmoid=0.00640
# Iteracion=958, L_sigmoid=0.00638
# Iteracion=959, L_sigmoid=0.00637
# Iteracion=960, L_sigmoid=0.00636
# Iteracion=961, L_sigmoid=0.00634
# Iteracion=962, L_sigmoid=0.00633
# Iteracion=963, L_sigmoid=0.00631
# Iteracion=964, L_sigmoid=0.00630
# Iteracion=965, L_sigmoid=0.00629
# Iteracion=966, L_sigmoid=0.00627
# Iteracion=967, L_sigmoid=0.00626
# Iteracion=968, L_sigmoid=0.00625
# Iteracion=969, L_sigmoid=0.00623
# Iteracion=970, L_sigmoid=0.00622
# Iteracion=971, L_sigmoid=0.00621
# Iteracion=972, L_sigmoid=0.00619
# Iteracion=973, L_sigmoid=0.00618
# Iteracion=974, L_sigmoid=0.00617
# Iteracion=975, L_sigmoid=0.00615
# Iteracion=976, L_sigmoid=0.00614
# Iteracion=977, L_sigmoid=0.00613
# Iteracion=978, L_sigmoid=0.00612
# Iteracion=979, L_sigmoid=0.00610
# Iteracion=980, L_sigmoid=0.00609
# Iteracion=981, L_sigmoid=0.00608
# Iteracion=982, L_sigmoid=0.00606
# Iteracion=983, L_sigmoid=0.00605
# Iteracion=984, L_sigmoid=0.00604
# Iteracion=985, L_sigmoid=0.00603
# Iteracion=986, L_sigmoid=0.00601
# Iteracion=987, L_sigmoid=0.00600
# Iteracion=988, L_sigmoid=0.00599
# Iteracion=989, L_sigmoid=0.00598
# Iteracion=990, L_sigmoid=0.00596
# Iteracion=991, L_sigmoid=0.00595
# Iteracion=992, L_sigmoid=0.00594
# Iteracion=993, L_sigmoid=0.00593
# Iteracion=994, L_sigmoid=0.00592
# Iteracion=995, L_sigmoid=0.00590
# Iteracion=996, L_sigmoid=0.00589
# Iteracion=997, L_sigmoid=0.00588
# Iteracion=998, L_sigmoid=0.00587
# Iteracion=999, L_sigmoid=0.00586

# %%
# Impresión de resultados

print(f"Valor final L_sigmoid : {L_sigmoid.data:.5f}")
print("Predicciones finales:", [y.data for y in yhat])
#show_graph(L_sigmoid)
# Out:
# Valor final L_sigmoid : 0.00586
# Predicciones finales: [0.07793418871418402, 0.9239933145312591, 0.9192931678367243, 0.0711075335358428]
