# %%
from michigrad.engine import Value
from michigrad.nn_modified import MLP_Modified
from michigrad.nn_modified import Linear
from michigrad.nn_modified import ReLU
from michigrad.nn_modified import Tanh
from michigrad.nn_modified import Sigmoid
from michigrad.visualize import show_graph

# %%
# Datos para entrenar al modelo

# 4 arreglos con 2 Value cada uno 
Xs = [
    [Value(0.0), Value(0.0)],
    [Value(1.0), Value(0.0)],
    [Value(0.0), Value(1.0)],
    [Value(1.0), Value(1.0)],
]

Ys = [
    Value(0.0),
    Value(1.0),
    Value(1.0),
    Value(0.0),
]

# %% [markdown]
# # Entrenamiento del modelo con ReLU

# %%
# Entrenamiento del modelo

layer_1 = Linear(2,2)
layer_2 = Linear(2,1)
activation_function = ReLU()

model = MLP_Modified([
    layer_1,
    activation_function,
    layer_2,
    activation_function
])

N = len(Ys)
learning_rate = 0.01
L_relu = Value(0)
yhat = []

for i in range(400):
    
    # Forward pass
    yhat = [model(x) for x in Xs]

    # Calculo Loss function
    L_relu = sum( (y - ypred)**2 for y, ypred in zip(Ys, yhat) ) * (Value(1) / Value(N))
    L_relu.name = "L_relu"
    
    # Gradiente en cero
    model.zero_grad()

    # Backpropagation
    L_relu.backward()

    # Update
    for p in model.parameters():
        p.data -= learning_rate * p.grad

    print(f'Iteracion={i}, L_relu={L_relu.data:.5f}')
# Out:
# Iteracion=0, L_relu=0.45656
# Iteracion=1, L_relu=0.45143
# Iteracion=2, L_relu=0.44183
# Iteracion=3, L_relu=0.43262
# Iteracion=4, L_relu=0.42378
# Iteracion=5, L_relu=0.41529
# Iteracion=6, L_relu=0.40716
# Iteracion=7, L_relu=0.39935
# Iteracion=8, L_relu=0.39186
# Iteracion=9, L_relu=0.38468
# Iteracion=10, L_relu=0.37778
# Iteracion=11, L_relu=0.37117
# Iteracion=12, L_relu=0.36483
# Iteracion=13, L_relu=0.35874
# Iteracion=14, L_relu=0.35291
# Iteracion=15, L_relu=0.34731
# Iteracion=16, L_relu=0.34193
# Iteracion=17, L_relu=0.33678
# Iteracion=18, L_relu=0.33184
# Iteracion=19, L_relu=0.32710
# Iteracion=20, L_relu=0.32255
# Iteracion=21, L_relu=0.31818
# Iteracion=22, L_relu=0.31400
# Iteracion=23, L_relu=0.30998
# Iteracion=24, L_relu=0.30613
# Iteracion=25, L_relu=0.30243
# Iteracion=26, L_relu=0.29889
# Iteracion=27, L_relu=0.29548
# Iteracion=28, L_relu=0.29222
# Iteracion=29, L_relu=0.28909
# Iteracion=30, L_relu=0.28608
# Iteracion=31, L_relu=0.28320
# Iteracion=32, L_relu=0.28043
# Iteracion=33, L_relu=0.27777
# Iteracion=34, L_relu=0.27522
# Iteracion=35, L_relu=0.27277
# Iteracion=36, L_relu=0.27042
# Iteracion=37, L_relu=0.26817
# Iteracion=38, L_relu=0.26600
# Iteracion=39, L_relu=0.26392
# Iteracion=40, L_relu=0.26192
# Iteracion=41, L_relu=0.26000
# Iteracion=42, L_relu=0.25816
# Iteracion=43, L_relu=0.25639
# Iteracion=44, L_relu=0.25469
# Iteracion=45, L_relu=0.25305
# Iteracion=46, L_relu=0.25148
# Iteracion=47, L_relu=0.24996
# Iteracion=48, L_relu=0.24851
# Iteracion=49, L_relu=0.24711
# Iteracion=50, L_relu=0.24576
# Iteracion=51, L_relu=0.24447
# Iteracion=52, L_relu=0.24322
# Iteracion=53, L_relu=0.24202
# Iteracion=54, L_relu=0.24086
# Iteracion=55, L_relu=0.23975
# Iteracion=56, L_relu=0.23867
# Iteracion=57, L_relu=0.23764
# Iteracion=58, L_relu=0.23664
# Iteracion=59, L_relu=0.23568
# Iteracion=60, L_relu=0.23475
# Iteracion=61, L_relu=0.23385
# Iteracion=62, L_relu=0.23299
# Iteracion=63, L_relu=0.23215
# Iteracion=64, L_relu=0.23134
# Iteracion=65, L_relu=0.23056
# Iteracion=66, L_relu=0.22980
# Iteracion=67, L_relu=0.22907
# Iteracion=68, L_relu=0.22836
# Iteracion=69, L_relu=0.22767
# Iteracion=70, L_relu=0.22701
# Iteracion=71, L_relu=0.22636
# Iteracion=72, L_relu=0.22574
# Iteracion=73, L_relu=0.22513
# Iteracion=74, L_relu=0.22454
# Iteracion=75, L_relu=0.22396
# Iteracion=76, L_relu=0.22341
# Iteracion=77, L_relu=0.22286
# Iteracion=78, L_relu=0.22233
# Iteracion=79, L_relu=0.22182
# Iteracion=80, L_relu=0.22132
# Iteracion=81, L_relu=0.22083
# Iteracion=82, L_relu=0.22035
# Iteracion=83, L_relu=0.21988
# Iteracion=84, L_relu=0.21943
# Iteracion=85, L_relu=0.21898
# Iteracion=86, L_relu=0.21854
# Iteracion=87, L_relu=0.21812
# Iteracion=88, L_relu=0.21770
# Iteracion=89, L_relu=0.21729
# Iteracion=90, L_relu=0.21688
# Iteracion=91, L_relu=0.21649
# Iteracion=92, L_relu=0.21610
# Iteracion=93, L_relu=0.21572
# Iteracion=94, L_relu=0.21536
# Iteracion=95, L_relu=0.21502
# Iteracion=96, L_relu=0.21470
# Iteracion=97, L_relu=0.21438
# Iteracion=98, L_relu=0.21406
# Iteracion=99, L_relu=0.21376
# Iteracion=100, L_relu=0.21346
# Iteracion=101, L_relu=0.21316
# Iteracion=102, L_relu=0.21288
# Iteracion=103, L_relu=0.21259
# Iteracion=104, L_relu=0.21231
# Iteracion=105, L_relu=0.21204
# Iteracion=106, L_relu=0.21177
# Iteracion=107, L_relu=0.21151
# Iteracion=108, L_relu=0.21125
# Iteracion=109, L_relu=0.21100
# Iteracion=110, L_relu=0.21074
# Iteracion=111, L_relu=0.21050
# Iteracion=112, L_relu=0.21025
# Iteracion=113, L_relu=0.21001
# Iteracion=114, L_relu=0.20977
# Iteracion=115, L_relu=0.20954
# Iteracion=116, L_relu=0.20931
# Iteracion=117, L_relu=0.20908
# Iteracion=118, L_relu=0.20885
# Iteracion=119, L_relu=0.20863
# Iteracion=120, L_relu=0.20841
# Iteracion=121, L_relu=0.20819
# Iteracion=122, L_relu=0.20797
# Iteracion=123, L_relu=0.20775
# Iteracion=124, L_relu=0.20754
# Iteracion=125, L_relu=0.20733
# Iteracion=126, L_relu=0.20712
# Iteracion=127, L_relu=0.20691
# Iteracion=128, L_relu=0.20670
# Iteracion=129, L_relu=0.20649
# Iteracion=130, L_relu=0.20629
# Iteracion=131, L_relu=0.20609
# Iteracion=132, L_relu=0.20588
# Iteracion=133, L_relu=0.20568
# Iteracion=134, L_relu=0.20548
# Iteracion=135, L_relu=0.20528
# Iteracion=136, L_relu=0.20509
# Iteracion=137, L_relu=0.20489
# Iteracion=138, L_relu=0.20469
# Iteracion=139, L_relu=0.20450
# Iteracion=140, L_relu=0.20430
# Iteracion=141, L_relu=0.20411
# Iteracion=142, L_relu=0.20391
# Iteracion=143, L_relu=0.20372
# Iteracion=144, L_relu=0.20353
# Iteracion=145, L_relu=0.20333
# Iteracion=146, L_relu=0.20314
# Iteracion=147, L_relu=0.20295
# Iteracion=148, L_relu=0.20276
# Iteracion=149, L_relu=0.20257
# Iteracion=150, L_relu=0.20237
# Iteracion=151, L_relu=0.20218
# Iteracion=152, L_relu=0.20199
# Iteracion=153, L_relu=0.20180
# Iteracion=154, L_relu=0.20161
# Iteracion=155, L_relu=0.20142
# Iteracion=156, L_relu=0.20123
# Iteracion=157, L_relu=0.20104
# Iteracion=158, L_relu=0.20085
# Iteracion=159, L_relu=0.20066
# Iteracion=160, L_relu=0.20047
# Iteracion=161, L_relu=0.20028
# Iteracion=162, L_relu=0.20010
# Iteracion=163, L_relu=0.19991
# Iteracion=164, L_relu=0.19972
# Iteracion=165, L_relu=0.19953
# Iteracion=166, L_relu=0.19934
# Iteracion=167, L_relu=0.19915
# Iteracion=168, L_relu=0.19896
# Iteracion=169, L_relu=0.19877
# Iteracion=170, L_relu=0.19867
# Iteracion=171, L_relu=0.19849
# Iteracion=172, L_relu=0.19839
# Iteracion=173, L_relu=0.19822
# Iteracion=174, L_relu=0.19812
# Iteracion=175, L_relu=0.19795
# Iteracion=176, L_relu=0.19786
# Iteracion=177, L_relu=0.19769
# Iteracion=178, L_relu=0.19760
# Iteracion=179, L_relu=0.19742
# Iteracion=180, L_relu=0.19735
# Iteracion=181, L_relu=0.19716
# Iteracion=182, L_relu=0.19709
# Iteracion=183, L_relu=0.19691
# Iteracion=184, L_relu=0.19684
# Iteracion=185, L_relu=0.19667
# Iteracion=186, L_relu=0.19658
# Iteracion=187, L_relu=0.19642
# Iteracion=188, L_relu=0.19633
# Iteracion=189, L_relu=0.19618
# Iteracion=190, L_relu=0.19607
# Iteracion=191, L_relu=0.19595
# Iteracion=192, L_relu=0.19582
# Iteracion=193, L_relu=0.19571
# Iteracion=194, L_relu=0.19557
# Iteracion=195, L_relu=0.19548
# Iteracion=196, L_relu=0.19532
# Iteracion=197, L_relu=0.19525
# Iteracion=198, L_relu=0.19508
# Iteracion=199, L_relu=0.19502
# Iteracion=200, L_relu=0.19485
# Iteracion=201, L_relu=0.19477
# Iteracion=202, L_relu=0.19463
# Iteracion=203, L_relu=0.19452
# Iteracion=204, L_relu=0.19441
# Iteracion=205, L_relu=0.19428
# Iteracion=206, L_relu=0.19419
# Iteracion=207, L_relu=0.19403
# Iteracion=208, L_relu=0.19398
# Iteracion=209, L_relu=0.19381
# Iteracion=210, L_relu=0.19374
# Iteracion=211, L_relu=0.19360
# Iteracion=212, L_relu=0.19350
# Iteracion=213, L_relu=0.19345
# Iteracion=214, L_relu=0.19328
# Iteracion=215, L_relu=0.19318
# Iteracion=216, L_relu=0.19313
# Iteracion=217, L_relu=0.19297
# Iteracion=218, L_relu=0.19287
# Iteracion=219, L_relu=0.19277
# Iteracion=220, L_relu=0.19265
# Iteracion=221, L_relu=0.19262
# Iteracion=222, L_relu=0.19247
# Iteracion=223, L_relu=0.19233
# Iteracion=224, L_relu=0.19232
# Iteracion=225, L_relu=0.19217
# Iteracion=226, L_relu=0.19202
# Iteracion=227, L_relu=0.19193
# Iteracion=228, L_relu=0.19187
# Iteracion=229, L_relu=0.19172
# Iteracion=230, L_relu=0.19162
# Iteracion=231, L_relu=0.19161
# Iteracion=232, L_relu=0.19148
# Iteracion=233, L_relu=0.19133
# Iteracion=234, L_relu=0.19129
# Iteracion=235, L_relu=0.19120
# Iteracion=236, L_relu=0.19104
# Iteracion=237, L_relu=0.19097
# Iteracion=238, L_relu=0.19092
# Iteracion=239, L_relu=0.19076
# Iteracion=240, L_relu=0.19066
# Iteracion=241, L_relu=0.19058
# Iteracion=242, L_relu=0.19044
# Iteracion=243, L_relu=0.19035
# Iteracion=244, L_relu=0.19031
# Iteracion=245, L_relu=0.19015
# Iteracion=246, L_relu=0.19014
# Iteracion=247, L_relu=0.19004
# Iteracion=248, L_relu=0.18989
# Iteracion=249, L_relu=0.18982
# Iteracion=250, L_relu=0.18977
# Iteracion=251, L_relu=0.18962
# Iteracion=252, L_relu=0.18950
# Iteracion=253, L_relu=0.18951
# Iteracion=254, L_relu=0.18936
# Iteracion=255, L_relu=0.18921
# Iteracion=256, L_relu=0.18912
# Iteracion=257, L_relu=0.18911
# Iteracion=258, L_relu=0.18901
# Iteracion=259, L_relu=0.18887
# Iteracion=260, L_relu=0.18879
# Iteracion=261, L_relu=0.18876
# Iteracion=262, L_relu=0.18861
# Iteracion=263, L_relu=0.18849
# Iteracion=264, L_relu=0.18845
# Iteracion=265, L_relu=0.18830
# Iteracion=266, L_relu=0.18829
# Iteracion=267, L_relu=0.18820
# Iteracion=268, L_relu=0.18806
# Iteracion=269, L_relu=0.18797
# Iteracion=270, L_relu=0.18796
# Iteracion=271, L_relu=0.18782
# Iteracion=272, L_relu=0.18768
# Iteracion=273, L_relu=0.18759
# Iteracion=274, L_relu=0.18758
# Iteracion=275, L_relu=0.18750
# Iteracion=276, L_relu=0.18736
# Iteracion=277, L_relu=0.18726
# Iteracion=278, L_relu=0.18720
# Iteracion=279, L_relu=0.18707
# Iteracion=280, L_relu=0.18698
# Iteracion=281, L_relu=0.18697
# Iteracion=282, L_relu=0.18689
# Iteracion=283, L_relu=0.18676
# Iteracion=284, L_relu=0.18666
# Iteracion=285, L_relu=0.18661
# Iteracion=286, L_relu=0.18647
# Iteracion=287, L_relu=0.18647
# Iteracion=288, L_relu=0.18638
# Iteracion=289, L_relu=0.18625
# Iteracion=290, L_relu=0.18614
# Iteracion=291, L_relu=0.18616
# Iteracion=292, L_relu=0.18603
# Iteracion=293, L_relu=0.18589
# Iteracion=294, L_relu=0.18587
# Iteracion=295, L_relu=0.18581
# Iteracion=296, L_relu=0.18568
# Iteracion=297, L_relu=0.18555
# Iteracion=298, L_relu=0.18547
# Iteracion=299, L_relu=0.18548
# Iteracion=300, L_relu=0.18540
# Iteracion=301, L_relu=0.18526
# Iteracion=302, L_relu=0.18516
# Iteracion=303, L_relu=0.18513
# Iteracion=304, L_relu=0.18499
# Iteracion=305, L_relu=0.18498
# Iteracion=306, L_relu=0.18492
# Iteracion=307, L_relu=0.18479
# Iteracion=308, L_relu=0.18467
# Iteracion=309, L_relu=0.18460
# Iteracion=310, L_relu=0.18459
# Iteracion=311, L_relu=0.18453
# Iteracion=312, L_relu=0.18440
# Iteracion=313, L_relu=0.18428
# Iteracion=314, L_relu=0.18427
# Iteracion=315, L_relu=0.18414
# Iteracion=316, L_relu=0.18409
# Iteracion=317, L_relu=0.18408
# Iteracion=318, L_relu=0.18395
# Iteracion=319, L_relu=0.18382
# Iteracion=320, L_relu=0.18381
# Iteracion=321, L_relu=0.18376
# Iteracion=322, L_relu=0.18364
# Iteracion=323, L_relu=0.18351
# Iteracion=324, L_relu=0.18345
# Iteracion=325, L_relu=0.18342
# Iteracion=326, L_relu=0.18339
# Iteracion=327, L_relu=0.18327
# Iteracion=328, L_relu=0.18314
# Iteracion=329, L_relu=0.18314
# Iteracion=330, L_relu=0.18309
# Iteracion=331, L_relu=0.18297
# Iteracion=332, L_relu=0.18284
# Iteracion=333, L_relu=0.18287
# Iteracion=334, L_relu=0.18279
# Iteracion=335, L_relu=0.18267
# Iteracion=336, L_relu=0.18255
# Iteracion=337, L_relu=0.18256
# Iteracion=338, L_relu=0.18244
# Iteracion=339, L_relu=0.18236
# Iteracion=340, L_relu=0.18239
# Iteracion=341, L_relu=0.18227
# Iteracion=342, L_relu=0.18215
# Iteracion=343, L_relu=0.18208
# Iteracion=344, L_relu=0.18211
# Iteracion=345, L_relu=0.18199
# Iteracion=346, L_relu=0.18187
# Iteracion=347, L_relu=0.18180
# Iteracion=348, L_relu=0.18183
# Iteracion=349, L_relu=0.18171
# Iteracion=350, L_relu=0.18159
# Iteracion=351, L_relu=0.18152
# Iteracion=352, L_relu=0.18155
# Iteracion=353, L_relu=0.18144
# Iteracion=354, L_relu=0.18132
# Iteracion=355, L_relu=0.18124
# Iteracion=356, L_relu=0.18129
# Iteracion=357, L_relu=0.18117
# Iteracion=358, L_relu=0.18106
# Iteracion=359, L_relu=0.18096
# Iteracion=360, L_relu=0.18090
# Iteracion=361, L_relu=0.18091
# Iteracion=362, L_relu=0.18086
# Iteracion=363, L_relu=0.18075
# Iteracion=364, L_relu=0.18064
# Iteracion=365, L_relu=0.18062
# Iteracion=366, L_relu=0.18061
# Iteracion=367, L_relu=0.18050
# Iteracion=368, L_relu=0.18039
# Iteracion=369, L_relu=0.18035
# Iteracion=370, L_relu=0.18030
# Iteracion=371, L_relu=0.18019
# Iteracion=372, L_relu=0.18017
# Iteracion=373, L_relu=0.18016
# Iteracion=374, L_relu=0.18005
# Iteracion=375, L_relu=0.17994
# Iteracion=376, L_relu=0.17989
# Iteracion=377, L_relu=0.17992
# Iteracion=378, L_relu=0.17981
# Iteracion=379, L_relu=0.17971
# Iteracion=380, L_relu=0.17962
# Iteracion=381, L_relu=0.17956
# Iteracion=382, L_relu=0.17955
# Iteracion=383, L_relu=0.17954
# Iteracion=384, L_relu=0.17943
# Iteracion=385, L_relu=0.17933
# Iteracion=386, L_relu=0.17928
# Iteracion=387, L_relu=0.17925
# Iteracion=388, L_relu=0.17914
# Iteracion=389, L_relu=0.17909
# Iteracion=390, L_relu=0.17913
# Iteracion=391, L_relu=0.17902
# Iteracion=392, L_relu=0.17892
# Iteracion=393, L_relu=0.17883
# Iteracion=394, L_relu=0.17878
# Iteracion=395, L_relu=0.17876
# Iteracion=396, L_relu=0.17871
# Iteracion=397, L_relu=0.17861
# Iteracion=398, L_relu=0.17859
# Iteracion=399, L_relu=0.17859

# %%
# Impresión de resultados

print(f"Valor final L_relu : {L_relu.data:.5f}")
print("Predicciones finales:", [y.data for y in yhat])
#show_graph(L_relu)
# Out:
# Valor final L_relu : 0.17859
# Predicciones finales: [0.40389879070724505, 0.8189777197808756, 0.40389879070724505, 0.40389879070724505]

# %% [markdown]
# # Entrenamiento del modelo con Tanh

# %%
# Entrenamiento del modelo

layer_1 = Linear(2,2)
layer_2 = Linear(2,1)
activation_function = Tanh()

model = MLP_Modified([
    layer_1,
    activation_function,
    layer_2,
    activation_function
])

N = len(Ys)
learning_rate = 0.01
L_tanh = Value(0)
yhat = []

for i in range(400):
    
    # Forward pass
    yhat = [model(x) for x in Xs]

    # Calculo Loss function
    L_tanh = sum( (y - ypred)**2 for y, ypred in zip(Ys, yhat) ) * (Value(1) / Value(N))
    L_tanh.name = "L_tanh"
    
    # Gradiente en cero
    model.zero_grad()

    # Backpropagation
    L_tanh.backward()

    # Update
    for p in model.parameters():
        p.data -= learning_rate * p.grad

    print(f'Iteracion={i}, L_tanh={L_tanh.data:.5f}')
# Out:
# Iteracion=0, L_tanh=0.87247
# Iteracion=1, L_tanh=0.84775
# Iteracion=2, L_tanh=0.82370
# Iteracion=3, L_tanh=0.80033
# Iteracion=4, L_tanh=0.77766
# Iteracion=5, L_tanh=0.75568
# Iteracion=6, L_tanh=0.73441
# Iteracion=7, L_tanh=0.71386
# Iteracion=8, L_tanh=0.69402
# Iteracion=9, L_tanh=0.67490
# Iteracion=10, L_tanh=0.65650
# Iteracion=11, L_tanh=0.63881
# Iteracion=12, L_tanh=0.62183
# Iteracion=13, L_tanh=0.60555
# Iteracion=14, L_tanh=0.58996
# Iteracion=15, L_tanh=0.57505
# Iteracion=16, L_tanh=0.56081
# Iteracion=17, L_tanh=0.54722
# Iteracion=18, L_tanh=0.53426
# Iteracion=19, L_tanh=0.52191
# Iteracion=20, L_tanh=0.51016
# Iteracion=21, L_tanh=0.49899
# Iteracion=22, L_tanh=0.48836
# Iteracion=23, L_tanh=0.47827
# Iteracion=24, L_tanh=0.46869
# Iteracion=25, L_tanh=0.45959
# Iteracion=26, L_tanh=0.45095
# Iteracion=27, L_tanh=0.44276
# Iteracion=28, L_tanh=0.43499
# Iteracion=29, L_tanh=0.42762
# Iteracion=30, L_tanh=0.42063
# Iteracion=31, L_tanh=0.41400
# Iteracion=32, L_tanh=0.40771
# Iteracion=33, L_tanh=0.40174
# Iteracion=34, L_tanh=0.39608
# Iteracion=35, L_tanh=0.39071
# Iteracion=36, L_tanh=0.38561
# Iteracion=37, L_tanh=0.38077
# Iteracion=38, L_tanh=0.37617
# Iteracion=39, L_tanh=0.37179
# Iteracion=40, L_tanh=0.36764
# Iteracion=41, L_tanh=0.36369
# Iteracion=42, L_tanh=0.35993
# Iteracion=43, L_tanh=0.35636
# Iteracion=44, L_tanh=0.35295
# Iteracion=45, L_tanh=0.34971
# Iteracion=46, L_tanh=0.34662
# Iteracion=47, L_tanh=0.34367
# Iteracion=48, L_tanh=0.34086
# Iteracion=49, L_tanh=0.33818
# Iteracion=50, L_tanh=0.33562
# Iteracion=51, L_tanh=0.33317
# Iteracion=52, L_tanh=0.33083
# Iteracion=53, L_tanh=0.32860
# Iteracion=54, L_tanh=0.32646
# Iteracion=55, L_tanh=0.32441
# Iteracion=56, L_tanh=0.32245
# Iteracion=57, L_tanh=0.32057
# Iteracion=58, L_tanh=0.31877
# Iteracion=59, L_tanh=0.31704
# Iteracion=60, L_tanh=0.31538
# Iteracion=61, L_tanh=0.31378
# Iteracion=62, L_tanh=0.31225
# Iteracion=63, L_tanh=0.31078
# Iteracion=64, L_tanh=0.30936
# Iteracion=65, L_tanh=0.30800
# Iteracion=66, L_tanh=0.30669
# Iteracion=67, L_tanh=0.30543
# Iteracion=68, L_tanh=0.30421
# Iteracion=69, L_tanh=0.30303
# Iteracion=70, L_tanh=0.30190
# Iteracion=71, L_tanh=0.30081
# Iteracion=72, L_tanh=0.29975
# Iteracion=73, L_tanh=0.29873
# Iteracion=74, L_tanh=0.29774
# Iteracion=75, L_tanh=0.29679
# Iteracion=76, L_tanh=0.29586
# Iteracion=77, L_tanh=0.29497
# Iteracion=78, L_tanh=0.29410
# Iteracion=79, L_tanh=0.29326
# Iteracion=80, L_tanh=0.29245
# Iteracion=81, L_tanh=0.29166
# Iteracion=82, L_tanh=0.29089
# Iteracion=83, L_tanh=0.29015
# Iteracion=84, L_tanh=0.28943
# Iteracion=85, L_tanh=0.28873
# Iteracion=86, L_tanh=0.28805
# Iteracion=87, L_tanh=0.28738
# Iteracion=88, L_tanh=0.28674
# Iteracion=89, L_tanh=0.28611
# Iteracion=90, L_tanh=0.28550
# Iteracion=91, L_tanh=0.28491
# Iteracion=92, L_tanh=0.28433
# Iteracion=93, L_tanh=0.28376
# Iteracion=94, L_tanh=0.28321
# Iteracion=95, L_tanh=0.28268
# Iteracion=96, L_tanh=0.28215
# Iteracion=97, L_tanh=0.28164
# Iteracion=98, L_tanh=0.28114
# Iteracion=99, L_tanh=0.28065
# Iteracion=100, L_tanh=0.28018
# Iteracion=101, L_tanh=0.27971
# Iteracion=102, L_tanh=0.27926
# Iteracion=103, L_tanh=0.27881
# Iteracion=104, L_tanh=0.27838
# Iteracion=105, L_tanh=0.27795
# Iteracion=106, L_tanh=0.27753
# Iteracion=107, L_tanh=0.27713
# Iteracion=108, L_tanh=0.27673
# Iteracion=109, L_tanh=0.27633
# Iteracion=110, L_tanh=0.27595
# Iteracion=111, L_tanh=0.27557
# Iteracion=112, L_tanh=0.27520
# Iteracion=113, L_tanh=0.27484
# Iteracion=114, L_tanh=0.27449
# Iteracion=115, L_tanh=0.27414
# Iteracion=116, L_tanh=0.27380
# Iteracion=117, L_tanh=0.27346
# Iteracion=118, L_tanh=0.27313
# Iteracion=119, L_tanh=0.27281
# Iteracion=120, L_tanh=0.27249
# Iteracion=121, L_tanh=0.27218
# Iteracion=122, L_tanh=0.27187
# Iteracion=123, L_tanh=0.27157
# Iteracion=124, L_tanh=0.27128
# Iteracion=125, L_tanh=0.27098
# Iteracion=126, L_tanh=0.27070
# Iteracion=127, L_tanh=0.27042
# Iteracion=128, L_tanh=0.27014
# Iteracion=129, L_tanh=0.26987
# Iteracion=130, L_tanh=0.26960
# Iteracion=131, L_tanh=0.26933
# Iteracion=132, L_tanh=0.26907
# Iteracion=133, L_tanh=0.26882
# Iteracion=134, L_tanh=0.26856
# Iteracion=135, L_tanh=0.26832
# Iteracion=136, L_tanh=0.26807
# Iteracion=137, L_tanh=0.26783
# Iteracion=138, L_tanh=0.26759
# Iteracion=139, L_tanh=0.26736
# Iteracion=140, L_tanh=0.26713
# Iteracion=141, L_tanh=0.26690
# Iteracion=142, L_tanh=0.26668
# Iteracion=143, L_tanh=0.26646
# Iteracion=144, L_tanh=0.26624
# Iteracion=145, L_tanh=0.26602
# Iteracion=146, L_tanh=0.26581
# Iteracion=147, L_tanh=0.26560
# Iteracion=148, L_tanh=0.26540
# Iteracion=149, L_tanh=0.26519
# Iteracion=150, L_tanh=0.26499
# Iteracion=151, L_tanh=0.26480
# Iteracion=152, L_tanh=0.26460
# Iteracion=153, L_tanh=0.26441
# Iteracion=154, L_tanh=0.26422
# Iteracion=155, L_tanh=0.26403
# Iteracion=156, L_tanh=0.26384
# Iteracion=157, L_tanh=0.26366
# Iteracion=158, L_tanh=0.26348
# Iteracion=159, L_tanh=0.26330
# Iteracion=160, L_tanh=0.26312
# Iteracion=161, L_tanh=0.26295
# Iteracion=162, L_tanh=0.26278
# Iteracion=163, L_tanh=0.26261
# Iteracion=164, L_tanh=0.26244
# Iteracion=165, L_tanh=0.26227
# Iteracion=166, L_tanh=0.26211
# Iteracion=167, L_tanh=0.26195
# Iteracion=168, L_tanh=0.26179
# Iteracion=169, L_tanh=0.26163
# Iteracion=170, L_tanh=0.26148
# Iteracion=171, L_tanh=0.26132
# Iteracion=172, L_tanh=0.26117
# Iteracion=173, L_tanh=0.26102
# Iteracion=174, L_tanh=0.26087
# Iteracion=175, L_tanh=0.26072
# Iteracion=176, L_tanh=0.26058
# Iteracion=177, L_tanh=0.26043
# Iteracion=178, L_tanh=0.26029
# Iteracion=179, L_tanh=0.26015
# Iteracion=180, L_tanh=0.26001
# Iteracion=181, L_tanh=0.25987
# Iteracion=182, L_tanh=0.25974
# Iteracion=183, L_tanh=0.25960
# Iteracion=184, L_tanh=0.25947
# Iteracion=185, L_tanh=0.25934
# Iteracion=186, L_tanh=0.25921
# Iteracion=187, L_tanh=0.25908
# Iteracion=188, L_tanh=0.25895
# Iteracion=189, L_tanh=0.25883
# Iteracion=190, L_tanh=0.25870
# Iteracion=191, L_tanh=0.25858
# Iteracion=192, L_tanh=0.25846
# Iteracion=193, L_tanh=0.25834
# Iteracion=194, L_tanh=0.25822
# Iteracion=195, L_tanh=0.25810
# Iteracion=196, L_tanh=0.25798
# Iteracion=197, L_tanh=0.25787
# Iteracion=198, L_tanh=0.25775
# Iteracion=199, L_tanh=0.25764
# Iteracion=200, L_tanh=0.25753
# Iteracion=201, L_tanh=0.25742
# Iteracion=202, L_tanh=0.25731
# Iteracion=203, L_tanh=0.25720
# Iteracion=204, L_tanh=0.25709
# Iteracion=205, L_tanh=0.25698
# Iteracion=206, L_tanh=0.25688
# Iteracion=207, L_tanh=0.25678
# Iteracion=208, L_tanh=0.25667
# Iteracion=209, L_tanh=0.25657
# Iteracion=210, L_tanh=0.25647
# Iteracion=211, L_tanh=0.25637
# Iteracion=212, L_tanh=0.25627
# Iteracion=213, L_tanh=0.25617
# Iteracion=214, L_tanh=0.25608
# Iteracion=215, L_tanh=0.25598
# Iteracion=216, L_tanh=0.25589
# Iteracion=217, L_tanh=0.25579
# Iteracion=218, L_tanh=0.25570
# Iteracion=219, L_tanh=0.25561
# Iteracion=220, L_tanh=0.25551
# Iteracion=221, L_tanh=0.25542
# Iteracion=222, L_tanh=0.25533
# Iteracion=223, L_tanh=0.25525
# Iteracion=224, L_tanh=0.25516
# Iteracion=225, L_tanh=0.25507
# Iteracion=226, L_tanh=0.25498
# Iteracion=227, L_tanh=0.25490
# Iteracion=228, L_tanh=0.25481
# Iteracion=229, L_tanh=0.25473
# Iteracion=230, L_tanh=0.25465
# Iteracion=231, L_tanh=0.25457
# Iteracion=232, L_tanh=0.25448
# Iteracion=233, L_tanh=0.25440
# Iteracion=234, L_tanh=0.25432
# Iteracion=235, L_tanh=0.25425
# Iteracion=236, L_tanh=0.25417
# Iteracion=237, L_tanh=0.25409
# Iteracion=238, L_tanh=0.25401
# Iteracion=239, L_tanh=0.25394
# Iteracion=240, L_tanh=0.25386
# Iteracion=241, L_tanh=0.25379
# Iteracion=242, L_tanh=0.25371
# Iteracion=243, L_tanh=0.25364
# Iteracion=244, L_tanh=0.25357
# Iteracion=245, L_tanh=0.25349
# Iteracion=246, L_tanh=0.25342
# Iteracion=247, L_tanh=0.25335
# Iteracion=248, L_tanh=0.25328
# Iteracion=249, L_tanh=0.25321
# Iteracion=250, L_tanh=0.25314
# Iteracion=251, L_tanh=0.25308
# Iteracion=252, L_tanh=0.25301
# Iteracion=253, L_tanh=0.25294
# Iteracion=254, L_tanh=0.25287
# Iteracion=255, L_tanh=0.25281
# Iteracion=256, L_tanh=0.25274
# Iteracion=257, L_tanh=0.25268
# Iteracion=258, L_tanh=0.25261
# Iteracion=259, L_tanh=0.25255
# Iteracion=260, L_tanh=0.25249
# Iteracion=261, L_tanh=0.25243
# Iteracion=262, L_tanh=0.25236
# Iteracion=263, L_tanh=0.25230
# Iteracion=264, L_tanh=0.25224
# Iteracion=265, L_tanh=0.25218
# Iteracion=266, L_tanh=0.25212
# Iteracion=267, L_tanh=0.25206
# Iteracion=268, L_tanh=0.25200
# Iteracion=269, L_tanh=0.25195
# Iteracion=270, L_tanh=0.25189
# Iteracion=271, L_tanh=0.25183
# Iteracion=272, L_tanh=0.25177
# Iteracion=273, L_tanh=0.25172
# Iteracion=274, L_tanh=0.25166
# Iteracion=275, L_tanh=0.25161
# Iteracion=276, L_tanh=0.25155
# Iteracion=277, L_tanh=0.25150
# Iteracion=278, L_tanh=0.25144
# Iteracion=279, L_tanh=0.25139
# Iteracion=280, L_tanh=0.25133
# Iteracion=281, L_tanh=0.25128
# Iteracion=282, L_tanh=0.25123
# Iteracion=283, L_tanh=0.25118
# Iteracion=284, L_tanh=0.25113
# Iteracion=285, L_tanh=0.25107
# Iteracion=286, L_tanh=0.25102
# Iteracion=287, L_tanh=0.25097
# Iteracion=288, L_tanh=0.25092
# Iteracion=289, L_tanh=0.25087
# Iteracion=290, L_tanh=0.25083
# Iteracion=291, L_tanh=0.25078
# Iteracion=292, L_tanh=0.25073
# Iteracion=293, L_tanh=0.25068
# Iteracion=294, L_tanh=0.25063
# Iteracion=295, L_tanh=0.25058
# Iteracion=296, L_tanh=0.25054
# Iteracion=297, L_tanh=0.25049
# Iteracion=298, L_tanh=0.25045
# Iteracion=299, L_tanh=0.25040
# Iteracion=300, L_tanh=0.25035
# Iteracion=301, L_tanh=0.25031
# Iteracion=302, L_tanh=0.25026
# Iteracion=303, L_tanh=0.25022
# Iteracion=304, L_tanh=0.25017
# Iteracion=305, L_tanh=0.25013
# Iteracion=306, L_tanh=0.25009
# Iteracion=307, L_tanh=0.25004
# Iteracion=308, L_tanh=0.25000
# Iteracion=309, L_tanh=0.24996
# Iteracion=310, L_tanh=0.24992
# Iteracion=311, L_tanh=0.24987
# Iteracion=312, L_tanh=0.24983
# Iteracion=313, L_tanh=0.24979
# Iteracion=314, L_tanh=0.24975
# Iteracion=315, L_tanh=0.24971
# Iteracion=316, L_tanh=0.24967
# Iteracion=317, L_tanh=0.24963
# Iteracion=318, L_tanh=0.24959
# Iteracion=319, L_tanh=0.24955
# Iteracion=320, L_tanh=0.24951
# Iteracion=321, L_tanh=0.24947
# Iteracion=322, L_tanh=0.24943
# Iteracion=323, L_tanh=0.24939
# Iteracion=324, L_tanh=0.24935
# Iteracion=325, L_tanh=0.24932
# Iteracion=326, L_tanh=0.24928
# Iteracion=327, L_tanh=0.24924
# Iteracion=328, L_tanh=0.24920
# Iteracion=329, L_tanh=0.24917
# Iteracion=330, L_tanh=0.24913
# Iteracion=331, L_tanh=0.24909
# Iteracion=332, L_tanh=0.24906
# Iteracion=333, L_tanh=0.24902
# Iteracion=334, L_tanh=0.24898
# Iteracion=335, L_tanh=0.24895
# Iteracion=336, L_tanh=0.24891
# Iteracion=337, L_tanh=0.24888
# Iteracion=338, L_tanh=0.24884
# Iteracion=339, L_tanh=0.24881
# Iteracion=340, L_tanh=0.24877
# Iteracion=341, L_tanh=0.24874
# Iteracion=342, L_tanh=0.24870
# Iteracion=343, L_tanh=0.24867
# Iteracion=344, L_tanh=0.24863
# Iteracion=345, L_tanh=0.24860
# Iteracion=346, L_tanh=0.24857
# Iteracion=347, L_tanh=0.24853
# Iteracion=348, L_tanh=0.24850
# Iteracion=349, L_tanh=0.24847
# Iteracion=350, L_tanh=0.24844
# Iteracion=351, L_tanh=0.24840
# Iteracion=352, L_tanh=0.24837
# Iteracion=353, L_tanh=0.24834
# Iteracion=354, L_tanh=0.24831
# Iteracion=355, L_tanh=0.24828
# Iteracion=356, L_tanh=0.24824
# Iteracion=357, L_tanh=0.24821
# Iteracion=358, L_tanh=0.24818
# Iteracion=359, L_tanh=0.24815
# Iteracion=360, L_tanh=0.24812
# Iteracion=361, L_tanh=0.24809
# Iteracion=362, L_tanh=0.24806
# Iteracion=363, L_tanh=0.24803
# Iteracion=364, L_tanh=0.24800
# Iteracion=365, L_tanh=0.24797
# Iteracion=366, L_tanh=0.24794
# Iteracion=367, L_tanh=0.24791
# Iteracion=368, L_tanh=0.24788
# Iteracion=369, L_tanh=0.24785
# Iteracion=370, L_tanh=0.24782
# Iteracion=371, L_tanh=0.24779
# Iteracion=372, L_tanh=0.24776
# Iteracion=373, L_tanh=0.24773
# Iteracion=374, L_tanh=0.24770
# Iteracion=375, L_tanh=0.24767
# Iteracion=376, L_tanh=0.24765
# Iteracion=377, L_tanh=0.24762
# Iteracion=378, L_tanh=0.24759
# Iteracion=379, L_tanh=0.24756
# Iteracion=380, L_tanh=0.24753
# Iteracion=381, L_tanh=0.24750
# Iteracion=382, L_tanh=0.24748
# Iteracion=383, L_tanh=0.24745
# Iteracion=384, L_tanh=0.24742
# Iteracion=385, L_tanh=0.24740
# Iteracion=386, L_tanh=0.24737
# Iteracion=387, L_tanh=0.24734
# Iteracion=388, L_tanh=0.24731
# Iteracion=389, L_tanh=0.24729
# Iteracion=390, L_tanh=0.24726
# Iteracion=391, L_tanh=0.24723
# Iteracion=392, L_tanh=0.24721
# Iteracion=393, L_tanh=0.24718
# Iteracion=394, L_tanh=0.24715
# Iteracion=395, L_tanh=0.24713
# Iteracion=396, L_tanh=0.24710
# Iteracion=397, L_tanh=0.24708
# Iteracion=398, L_tanh=0.24705
# Iteracion=399, L_tanh=0.24703

# %%
# Impresión de resultados

print(f"Valor final L_tanh : {L_tanh.data:.5f}")
print("Predicciones finales:", [y.data for y in yhat])
#show_graph(L_tanh)
# Out:
# Valor final L_tanh : 0.24703
# Predicciones finales: [0.5774992326295295, 0.5437286579123115, 0.4614108141501618, 0.3953897789485372]

# %% [markdown]
# # Entrenamiento del modelo con Sigmoide

# %%
# Entrenamiento del modelo

layer_1 = Linear(2,2)
layer_2 = Linear(2,1)
activation_function = Sigmoid()

model = MLP_Modified([
    layer_1,
    activation_function,
    layer_2,
    activation_function
])

N = len(Ys)
learning_rate = 0.01
L_sigmoid = Value(0)
yhat = []

for i in range(400):
    
    # Forward pass
    yhat = [model(x) for x in Xs]

    # Calculo Loss function
    L_sigmoid = sum( (y - ypred)**2 for y, ypred in zip(Ys, yhat) ) * (Value(1) / Value(N))
    L_sigmoid.name = "L_sigmoid"
    
    # Gradiente en cero
    model.zero_grad()

    # Backpropagation
    L_sigmoid.backward()

    # Update
    for p in model.parameters():
        p.data -= learning_rate * p.grad

    print(f'Iteracion={i}, L_sigmoid={L_sigmoid.data:.5f}')
# Out:
# Iteracion=0, L_sigmoid=0.28164
# Iteracion=1, L_sigmoid=0.28153
# Iteracion=2, L_sigmoid=0.28142
# Iteracion=3, L_sigmoid=0.28132
# Iteracion=4, L_sigmoid=0.28121
# Iteracion=5, L_sigmoid=0.28111
# Iteracion=6, L_sigmoid=0.28100
# Iteracion=7, L_sigmoid=0.28090
# Iteracion=8, L_sigmoid=0.28079
# Iteracion=9, L_sigmoid=0.28069
# Iteracion=10, L_sigmoid=0.28058
# Iteracion=11, L_sigmoid=0.28048
# Iteracion=12, L_sigmoid=0.28037
# Iteracion=13, L_sigmoid=0.28027
# Iteracion=14, L_sigmoid=0.28017
# Iteracion=15, L_sigmoid=0.28006
# Iteracion=16, L_sigmoid=0.27996
# Iteracion=17, L_sigmoid=0.27986
# Iteracion=18, L_sigmoid=0.27976
# Iteracion=19, L_sigmoid=0.27965
# Iteracion=20, L_sigmoid=0.27955
# Iteracion=21, L_sigmoid=0.27945
# Iteracion=22, L_sigmoid=0.27935
# Iteracion=23, L_sigmoid=0.27925
# Iteracion=24, L_sigmoid=0.27915
# Iteracion=25, L_sigmoid=0.27905
# Iteracion=26, L_sigmoid=0.27895
# Iteracion=27, L_sigmoid=0.27885
# Iteracion=28, L_sigmoid=0.27875
# Iteracion=29, L_sigmoid=0.27865
# Iteracion=30, L_sigmoid=0.27855
# Iteracion=31, L_sigmoid=0.27845
# Iteracion=32, L_sigmoid=0.27835
# Iteracion=33, L_sigmoid=0.27826
# Iteracion=34, L_sigmoid=0.27816
# Iteracion=35, L_sigmoid=0.27806
# Iteracion=36, L_sigmoid=0.27796
# Iteracion=37, L_sigmoid=0.27787
# Iteracion=38, L_sigmoid=0.27777
# Iteracion=39, L_sigmoid=0.27767
# Iteracion=40, L_sigmoid=0.27758
# Iteracion=41, L_sigmoid=0.27748
# Iteracion=42, L_sigmoid=0.27738
# Iteracion=43, L_sigmoid=0.27729
# Iteracion=44, L_sigmoid=0.27719
# Iteracion=45, L_sigmoid=0.27710
# Iteracion=46, L_sigmoid=0.27700
# Iteracion=47, L_sigmoid=0.27691
# Iteracion=48, L_sigmoid=0.27682
# Iteracion=49, L_sigmoid=0.27672
# Iteracion=50, L_sigmoid=0.27663
# Iteracion=51, L_sigmoid=0.27654
# Iteracion=52, L_sigmoid=0.27644
# Iteracion=53, L_sigmoid=0.27635
# Iteracion=54, L_sigmoid=0.27626
# Iteracion=55, L_sigmoid=0.27616
# Iteracion=56, L_sigmoid=0.27607
# Iteracion=57, L_sigmoid=0.27598
# Iteracion=58, L_sigmoid=0.27589
# Iteracion=59, L_sigmoid=0.27580
# Iteracion=60, L_sigmoid=0.27571
# Iteracion=61, L_sigmoid=0.27562
# Iteracion=62, L_sigmoid=0.27553
# Iteracion=63, L_sigmoid=0.27544
# Iteracion=64, L_sigmoid=0.27535
# Iteracion=65, L_sigmoid=0.27526
# Iteracion=66, L_sigmoid=0.27517
# Iteracion=67, L_sigmoid=0.27508
# Iteracion=68, L_sigmoid=0.27499
# Iteracion=69, L_sigmoid=0.27490
# Iteracion=70, L_sigmoid=0.27481
# Iteracion=71, L_sigmoid=0.27472
# Iteracion=72, L_sigmoid=0.27464
# Iteracion=73, L_sigmoid=0.27455
# Iteracion=74, L_sigmoid=0.27446
# Iteracion=75, L_sigmoid=0.27437
# Iteracion=76, L_sigmoid=0.27429
# Iteracion=77, L_sigmoid=0.27420
# Iteracion=78, L_sigmoid=0.27411
# Iteracion=79, L_sigmoid=0.27403
# Iteracion=80, L_sigmoid=0.27394
# Iteracion=81, L_sigmoid=0.27386
# Iteracion=82, L_sigmoid=0.27377
# Iteracion=83, L_sigmoid=0.27369
# Iteracion=84, L_sigmoid=0.27360
# Iteracion=85, L_sigmoid=0.27352
# Iteracion=86, L_sigmoid=0.27343
# Iteracion=87, L_sigmoid=0.27335
# Iteracion=88, L_sigmoid=0.27327
# Iteracion=89, L_sigmoid=0.27318
# Iteracion=90, L_sigmoid=0.27310
# Iteracion=91, L_sigmoid=0.27302
# Iteracion=92, L_sigmoid=0.27293
# Iteracion=93, L_sigmoid=0.27285
# Iteracion=94, L_sigmoid=0.27277
# Iteracion=95, L_sigmoid=0.27269
# Iteracion=96, L_sigmoid=0.27261
# Iteracion=97, L_sigmoid=0.27252
# Iteracion=98, L_sigmoid=0.27244
# Iteracion=99, L_sigmoid=0.27236
# Iteracion=100, L_sigmoid=0.27228
# Iteracion=101, L_sigmoid=0.27220
# Iteracion=102, L_sigmoid=0.27212
# Iteracion=103, L_sigmoid=0.27204
# Iteracion=104, L_sigmoid=0.27196
# Iteracion=105, L_sigmoid=0.27188
# Iteracion=106, L_sigmoid=0.27180
# Iteracion=107, L_sigmoid=0.27172
# Iteracion=108, L_sigmoid=0.27164
# Iteracion=109, L_sigmoid=0.27157
# Iteracion=110, L_sigmoid=0.27149
# Iteracion=111, L_sigmoid=0.27141
# Iteracion=112, L_sigmoid=0.27133
# Iteracion=113, L_sigmoid=0.27125
# Iteracion=114, L_sigmoid=0.27118
# Iteracion=115, L_sigmoid=0.27110
# Iteracion=116, L_sigmoid=0.27102
# Iteracion=117, L_sigmoid=0.27095
# Iteracion=118, L_sigmoid=0.27087
# Iteracion=119, L_sigmoid=0.27079
# Iteracion=120, L_sigmoid=0.27072
# Iteracion=121, L_sigmoid=0.27064
# Iteracion=122, L_sigmoid=0.27057
# Iteracion=123, L_sigmoid=0.27049
# Iteracion=124, L_sigmoid=0.27042
# Iteracion=125, L_sigmoid=0.27034
# Iteracion=126, L_sigmoid=0.27027
# Iteracion=127, L_sigmoid=0.27019
# Iteracion=128, L_sigmoid=0.27012
# Iteracion=129, L_sigmoid=0.27005
# Iteracion=130, L_sigmoid=0.26997
# Iteracion=131, L_sigmoid=0.26990
# Iteracion=132, L_sigmoid=0.26983
# Iteracion=133, L_sigmoid=0.26975
# Iteracion=134, L_sigmoid=0.26968
# Iteracion=135, L_sigmoid=0.26961
# Iteracion=136, L_sigmoid=0.26954
# Iteracion=137, L_sigmoid=0.26947
# Iteracion=138, L_sigmoid=0.26939
# Iteracion=139, L_sigmoid=0.26932
# Iteracion=140, L_sigmoid=0.26925
# Iteracion=141, L_sigmoid=0.26918
# Iteracion=142, L_sigmoid=0.26911
# Iteracion=143, L_sigmoid=0.26904
# Iteracion=144, L_sigmoid=0.26897
# Iteracion=145, L_sigmoid=0.26890
# Iteracion=146, L_sigmoid=0.26883
# Iteracion=147, L_sigmoid=0.26876
# Iteracion=148, L_sigmoid=0.26869
# Iteracion=149, L_sigmoid=0.26862
# Iteracion=150, L_sigmoid=0.26855
# Iteracion=151, L_sigmoid=0.26848
# Iteracion=152, L_sigmoid=0.26842
# Iteracion=153, L_sigmoid=0.26835
# Iteracion=154, L_sigmoid=0.26828
# Iteracion=155, L_sigmoid=0.26821
# Iteracion=156, L_sigmoid=0.26815
# Iteracion=157, L_sigmoid=0.26808
# Iteracion=158, L_sigmoid=0.26801
# Iteracion=159, L_sigmoid=0.26794
# Iteracion=160, L_sigmoid=0.26788
# Iteracion=161, L_sigmoid=0.26781
# Iteracion=162, L_sigmoid=0.26775
# Iteracion=163, L_sigmoid=0.26768
# Iteracion=164, L_sigmoid=0.26761
# Iteracion=165, L_sigmoid=0.26755
# Iteracion=166, L_sigmoid=0.26748
# Iteracion=167, L_sigmoid=0.26742
# Iteracion=168, L_sigmoid=0.26735
# Iteracion=169, L_sigmoid=0.26729
# Iteracion=170, L_sigmoid=0.26722
# Iteracion=171, L_sigmoid=0.26716
# Iteracion=172, L_sigmoid=0.26710
# Iteracion=173, L_sigmoid=0.26703
# Iteracion=174, L_sigmoid=0.26697
# Iteracion=175, L_sigmoid=0.26691
# Iteracion=176, L_sigmoid=0.26684
# Iteracion=177, L_sigmoid=0.26678
# Iteracion=178, L_sigmoid=0.26672
# Iteracion=179, L_sigmoid=0.26665
# Iteracion=180, L_sigmoid=0.26659
# Iteracion=181, L_sigmoid=0.26653
# Iteracion=182, L_sigmoid=0.26647
# Iteracion=183, L_sigmoid=0.26641
# Iteracion=184, L_sigmoid=0.26635
# Iteracion=185, L_sigmoid=0.26628
# Iteracion=186, L_sigmoid=0.26622
# Iteracion=187, L_sigmoid=0.26616
# Iteracion=188, L_sigmoid=0.26610
# Iteracion=189, L_sigmoid=0.26604
# Iteracion=190, L_sigmoid=0.26598
# Iteracion=191, L_sigmoid=0.26592
# Iteracion=192, L_sigmoid=0.26586
# Iteracion=193, L_sigmoid=0.26580
# Iteracion=194, L_sigmoid=0.26574
# Iteracion=195, L_sigmoid=0.26568
# Iteracion=196, L_sigmoid=0.26563
# Iteracion=197, L_sigmoid=0.26557
# Iteracion=198, L_sigmoid=0.26551
# Iteracion=199, L_sigmoid=0.26545
# Iteracion=200, L_sigmoid=0.26539
# Iteracion=201, L_sigmoid=0.26533
# Iteracion=202, L_sigmoid=0.26528
# Iteracion=203, L_sigmoid=0.26522
# Iteracion=204, L_sigmoid=0.26516
# Iteracion=205, L_sigmoid=0.26511
# Iteracion=206, L_sigmoid=0.26505
# Iteracion=207, L_sigmoid=0.26499
# Iteracion=208, L_sigmoid=0.26494
# Iteracion=209, L_sigmoid=0.26488
# Iteracion=210, L_sigmoid=0.26482
# Iteracion=211, L_sigmoid=0.26477
# Iteracion=212, L_sigmoid=0.26471
# Iteracion=213, L_sigmoid=0.26466
# Iteracion=214, L_sigmoid=0.26460
# Iteracion=215, L_sigmoid=0.26455
# Iteracion=216, L_sigmoid=0.26449
# Iteracion=217, L_sigmoid=0.26444
# Iteracion=218, L_sigmoid=0.26438
# Iteracion=219, L_sigmoid=0.26433
# Iteracion=220, L_sigmoid=0.26427
# Iteracion=221, L_sigmoid=0.26422
# Iteracion=222, L_sigmoid=0.26417
# Iteracion=223, L_sigmoid=0.26411
# Iteracion=224, L_sigmoid=0.26406
# Iteracion=225, L_sigmoid=0.26401
# Iteracion=226, L_sigmoid=0.26395
# Iteracion=227, L_sigmoid=0.26390
# Iteracion=228, L_sigmoid=0.26385
# Iteracion=229, L_sigmoid=0.26379
# Iteracion=230, L_sigmoid=0.26374
# Iteracion=231, L_sigmoid=0.26369
# Iteracion=232, L_sigmoid=0.26364
# Iteracion=233, L_sigmoid=0.26359
# Iteracion=234, L_sigmoid=0.26354
# Iteracion=235, L_sigmoid=0.26348
# Iteracion=236, L_sigmoid=0.26343
# Iteracion=237, L_sigmoid=0.26338
# Iteracion=238, L_sigmoid=0.26333
# Iteracion=239, L_sigmoid=0.26328
# Iteracion=240, L_sigmoid=0.26323
# Iteracion=241, L_sigmoid=0.26318
# Iteracion=242, L_sigmoid=0.26313
# Iteracion=243, L_sigmoid=0.26308
# Iteracion=244, L_sigmoid=0.26303
# Iteracion=245, L_sigmoid=0.26298
# Iteracion=246, L_sigmoid=0.26293
# Iteracion=247, L_sigmoid=0.26288
# Iteracion=248, L_sigmoid=0.26283
# Iteracion=249, L_sigmoid=0.26278
# Iteracion=250, L_sigmoid=0.26274
# Iteracion=251, L_sigmoid=0.26269
# Iteracion=252, L_sigmoid=0.26264
# Iteracion=253, L_sigmoid=0.26259
# Iteracion=254, L_sigmoid=0.26254
# Iteracion=255, L_sigmoid=0.26250
# Iteracion=256, L_sigmoid=0.26245
# Iteracion=257, L_sigmoid=0.26240
# Iteracion=258, L_sigmoid=0.26235
# Iteracion=259, L_sigmoid=0.26231
# Iteracion=260, L_sigmoid=0.26226
# Iteracion=261, L_sigmoid=0.26221
# Iteracion=262, L_sigmoid=0.26217
# Iteracion=263, L_sigmoid=0.26212
# Iteracion=264, L_sigmoid=0.26207
# Iteracion=265, L_sigmoid=0.26203
# Iteracion=266, L_sigmoid=0.26198
# Iteracion=267, L_sigmoid=0.26194
# Iteracion=268, L_sigmoid=0.26189
# Iteracion=269, L_sigmoid=0.26185
# Iteracion=270, L_sigmoid=0.26180
# Iteracion=271, L_sigmoid=0.26176
# Iteracion=272, L_sigmoid=0.26171
# Iteracion=273, L_sigmoid=0.26167
# Iteracion=274, L_sigmoid=0.26162
# Iteracion=275, L_sigmoid=0.26158
# Iteracion=276, L_sigmoid=0.26153
# Iteracion=277, L_sigmoid=0.26149
# Iteracion=278, L_sigmoid=0.26145
# Iteracion=279, L_sigmoid=0.26140
# Iteracion=280, L_sigmoid=0.26136
# Iteracion=281, L_sigmoid=0.26131
# Iteracion=282, L_sigmoid=0.26127
# Iteracion=283, L_sigmoid=0.26123
# Iteracion=284, L_sigmoid=0.26119
# Iteracion=285, L_sigmoid=0.26114
# Iteracion=286, L_sigmoid=0.26110
# Iteracion=287, L_sigmoid=0.26106
# Iteracion=288, L_sigmoid=0.26102
# Iteracion=289, L_sigmoid=0.26097
# Iteracion=290, L_sigmoid=0.26093
# Iteracion=291, L_sigmoid=0.26089
# Iteracion=292, L_sigmoid=0.26085
# Iteracion=293, L_sigmoid=0.26081
# Iteracion=294, L_sigmoid=0.26077
# Iteracion=295, L_sigmoid=0.26072
# Iteracion=296, L_sigmoid=0.26068
# Iteracion=297, L_sigmoid=0.26064
# Iteracion=298, L_sigmoid=0.26060
# Iteracion=299, L_sigmoid=0.26056
# Iteracion=300, L_sigmoid=0.26052
# Iteracion=301, L_sigmoid=0.26048
# Iteracion=302, L_sigmoid=0.26044
# Iteracion=303, L_sigmoid=0.26040
# Iteracion=304, L_sigmoid=0.26036
# Iteracion=305, L_sigmoid=0.26032
# Iteracion=306, L_sigmoid=0.26028
# Iteracion=307, L_sigmoid=0.26024
# Iteracion=308, L_sigmoid=0.26020
# Iteracion=309, L_sigmoid=0.26016
# Iteracion=310, L_sigmoid=0.26013
# Iteracion=311, L_sigmoid=0.26009
# Iteracion=312, L_sigmoid=0.26005
# Iteracion=313, L_sigmoid=0.26001
# Iteracion=314, L_sigmoid=0.25997
# Iteracion=315, L_sigmoid=0.25993
# Iteracion=316, L_sigmoid=0.25990
# Iteracion=317, L_sigmoid=0.25986
# Iteracion=318, L_sigmoid=0.25982
# Iteracion=319, L_sigmoid=0.25978
# Iteracion=320, L_sigmoid=0.25975
# Iteracion=321, L_sigmoid=0.25971
# Iteracion=322, L_sigmoid=0.25967
# Iteracion=323, L_sigmoid=0.25963
# Iteracion=324, L_sigmoid=0.25960
# Iteracion=325, L_sigmoid=0.25956
# Iteracion=326, L_sigmoid=0.25952
# Iteracion=327, L_sigmoid=0.25949
# Iteracion=328, L_sigmoid=0.25945
# Iteracion=329, L_sigmoid=0.25941
# Iteracion=330, L_sigmoid=0.25938
# Iteracion=331, L_sigmoid=0.25934
# Iteracion=332, L_sigmoid=0.25931
# Iteracion=333, L_sigmoid=0.25927
# Iteracion=334, L_sigmoid=0.25924
# Iteracion=335, L_sigmoid=0.25920
# Iteracion=336, L_sigmoid=0.25917
# Iteracion=337, L_sigmoid=0.25913
# Iteracion=338, L_sigmoid=0.25910
# Iteracion=339, L_sigmoid=0.25906
# Iteracion=340, L_sigmoid=0.25903
# Iteracion=341, L_sigmoid=0.25899
# Iteracion=342, L_sigmoid=0.25896
# Iteracion=343, L_sigmoid=0.25892
# Iteracion=344, L_sigmoid=0.25889
# Iteracion=345, L_sigmoid=0.25885
# Iteracion=346, L_sigmoid=0.25882
# Iteracion=347, L_sigmoid=0.25879
# Iteracion=348, L_sigmoid=0.25875
# Iteracion=349, L_sigmoid=0.25872
# Iteracion=350, L_sigmoid=0.25869
# Iteracion=351, L_sigmoid=0.25865
# Iteracion=352, L_sigmoid=0.25862
# Iteracion=353, L_sigmoid=0.25859
# Iteracion=354, L_sigmoid=0.25855
# Iteracion=355, L_sigmoid=0.25852
# Iteracion=356, L_sigmoid=0.25849
# Iteracion=357, L_sigmoid=0.25846
# Iteracion=358, L_sigmoid=0.25842
# Iteracion=359, L_sigmoid=0.25839
# Iteracion=360, L_sigmoid=0.25836
# Iteracion=361, L_sigmoid=0.25833
# Iteracion=362, L_sigmoid=0.25830
# Iteracion=363, L_sigmoid=0.25826
# Iteracion=364, L_sigmoid=0.25823
# Iteracion=365, L_sigmoid=0.25820
# Iteracion=366, L_sigmoid=0.25817
# Iteracion=367, L_sigmoid=0.25814
# Iteracion=368, L_sigmoid=0.25811
# Iteracion=369, L_sigmoid=0.25808
# Iteracion=370, L_sigmoid=0.25805
# Iteracion=371, L_sigmoid=0.25802
# Iteracion=372, L_sigmoid=0.25799
# Iteracion=373, L_sigmoid=0.25795
# Iteracion=374, L_sigmoid=0.25792
# Iteracion=375, L_sigmoid=0.25789
# Iteracion=376, L_sigmoid=0.25786
# Iteracion=377, L_sigmoid=0.25783
# Iteracion=378, L_sigmoid=0.25780
# Iteracion=379, L_sigmoid=0.25777
# Iteracion=380, L_sigmoid=0.25774
# Iteracion=381, L_sigmoid=0.25772
# Iteracion=382, L_sigmoid=0.25769
# Iteracion=383, L_sigmoid=0.25766
# Iteracion=384, L_sigmoid=0.25763
# Iteracion=385, L_sigmoid=0.25760
# Iteracion=386, L_sigmoid=0.25757
# Iteracion=387, L_sigmoid=0.25754
# Iteracion=388, L_sigmoid=0.25751
# Iteracion=389, L_sigmoid=0.25748
# Iteracion=390, L_sigmoid=0.25745
# Iteracion=391, L_sigmoid=0.25743
# Iteracion=392, L_sigmoid=0.25740
# Iteracion=393, L_sigmoid=0.25737
# Iteracion=394, L_sigmoid=0.25734
# Iteracion=395, L_sigmoid=0.25731
# Iteracion=396, L_sigmoid=0.25729
# Iteracion=397, L_sigmoid=0.25726
# Iteracion=398, L_sigmoid=0.25723
# Iteracion=399, L_sigmoid=0.25720

# %%
# Impresión de resultados

print(f"Valor final L_sigmoid : {L_sigmoid.data:.5f}")
print("Predicciones finales:", [y.data for y in yhat])
#show_graph(L_sigmoid)
# Out:
# Valor final L_sigmoid : 0.25720
# Predicciones finales: [0.4456926357985719, 0.4221483763018783, 0.41871924567122787, 0.3979561472146261]
