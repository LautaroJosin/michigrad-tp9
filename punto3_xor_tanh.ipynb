# %%
from michigrad.engine import Value
from michigrad.nn_modified import MLP_Modified
from michigrad.nn_modified import Linear
from michigrad.nn_modified import Tanh
from michigrad.visualize import show_graph

# %%
# Datos para entrenar al modelo

# Modifico Xs por como funciona Tanh, devuelve valores entre -1 y 1.
# -1 = 0
# 1 = 1
Xs = [
    [Value(-1.0), Value(-1.0)],
    [Value(1.0), Value(-1.0)],
    [Value(-1.0), Value(1.0)],
    [Value(1.0), Value(1.0)],
]

Ys = [
    Value(-1.0),
    Value(1.0),
    Value(1.0),
    Value(-1.0),
]

# %% [markdown]
# # Entrenamiento del modelo con Tanh

# %%
# Entrenamiento del modelo

layer_1 = Linear(2,2)
layer_2 = Linear(2,1)
activation_function = Tanh()

model = MLP_Modified([
    layer_1,
    activation_function,
    layer_2,
    activation_function
])

N = len(Ys)
learning_rate = 0.1
L_tanh = Value(0)
yhat = []

for i in range(500):
    
    # Forward pass
    yhat = [model(x) for x in Xs]

    # Calculo Loss function
    L_tanh = sum( (y - ypred)**2 for y, ypred in zip(Ys, yhat) ) * (Value(1) / Value(N))
    L_tanh.name = "L_tanh"
    
    # Gradiente en cero
    model.zero_grad()

    # Backpropagation
    L_tanh.backward()

    # Update
    for p in model.parameters():
        p.data -= learning_rate * p.grad

    print(f'Iteracion={i}, L_tanh={L_tanh.data:.5f}')
# Out:
# Iteracion=0, L_tanh=1.11837
# Iteracion=1, L_tanh=1.08929
# Iteracion=2, L_tanh=1.06924
# Iteracion=3, L_tanh=1.05483
# Iteracion=4, L_tanh=1.04391
# Iteracion=5, L_tanh=1.03521
# Iteracion=6, L_tanh=1.02802
# Iteracion=7, L_tanh=1.02191
# Iteracion=8, L_tanh=1.01665
# Iteracion=9, L_tanh=1.01210
# Iteracion=10, L_tanh=1.00815
# Iteracion=11, L_tanh=1.00472
# Iteracion=12, L_tanh=1.00175
# Iteracion=13, L_tanh=0.99917
# Iteracion=14, L_tanh=0.99692
# Iteracion=15, L_tanh=0.99493
# Iteracion=16, L_tanh=0.99316
# Iteracion=17, L_tanh=0.99155
# Iteracion=18, L_tanh=0.99007
# Iteracion=19, L_tanh=0.98867
# Iteracion=20, L_tanh=0.98732
# Iteracion=21, L_tanh=0.98599
# Iteracion=22, L_tanh=0.98466
# Iteracion=23, L_tanh=0.98331
# Iteracion=24, L_tanh=0.98191
# Iteracion=25, L_tanh=0.98045
# Iteracion=26, L_tanh=0.97891
# Iteracion=27, L_tanh=0.97727
# Iteracion=28, L_tanh=0.97553
# Iteracion=29, L_tanh=0.97366
# Iteracion=30, L_tanh=0.97165
# Iteracion=31, L_tanh=0.96949
# Iteracion=32, L_tanh=0.96716
# Iteracion=33, L_tanh=0.96465
# Iteracion=34, L_tanh=0.96193
# Iteracion=35, L_tanh=0.95899
# Iteracion=36, L_tanh=0.95581
# Iteracion=37, L_tanh=0.95237
# Iteracion=38, L_tanh=0.94866
# Iteracion=39, L_tanh=0.94464
# Iteracion=40, L_tanh=0.94031
# Iteracion=41, L_tanh=0.93563
# Iteracion=42, L_tanh=0.93058
# Iteracion=43, L_tanh=0.92514
# Iteracion=44, L_tanh=0.91929
# Iteracion=45, L_tanh=0.91299
# Iteracion=46, L_tanh=0.90623
# Iteracion=47, L_tanh=0.89898
# Iteracion=48, L_tanh=0.89120
# Iteracion=49, L_tanh=0.88289
# Iteracion=50, L_tanh=0.87401
# Iteracion=51, L_tanh=0.86453
# Iteracion=52, L_tanh=0.85445
# Iteracion=53, L_tanh=0.84373
# Iteracion=54, L_tanh=0.83236
# Iteracion=55, L_tanh=0.82032
# Iteracion=56, L_tanh=0.80759
# Iteracion=57, L_tanh=0.79418
# Iteracion=58, L_tanh=0.78007
# Iteracion=59, L_tanh=0.76526
# Iteracion=60, L_tanh=0.74976
# Iteracion=61, L_tanh=0.73358
# Iteracion=62, L_tanh=0.71673
# Iteracion=63, L_tanh=0.69926
# Iteracion=64, L_tanh=0.68119
# Iteracion=65, L_tanh=0.66258
# Iteracion=66, L_tanh=0.64347
# Iteracion=67, L_tanh=0.62394
# Iteracion=68, L_tanh=0.60407
# Iteracion=69, L_tanh=0.58393
# Iteracion=70, L_tanh=0.56363
# Iteracion=71, L_tanh=0.54325
# Iteracion=72, L_tanh=0.52289
# Iteracion=73, L_tanh=0.50266
# Iteracion=74, L_tanh=0.48265
# Iteracion=75, L_tanh=0.46295
# Iteracion=76, L_tanh=0.44364
# Iteracion=77, L_tanh=0.42480
# Iteracion=78, L_tanh=0.40650
# Iteracion=79, L_tanh=0.38878
# Iteracion=80, L_tanh=0.37169
# Iteracion=81, L_tanh=0.35526
# Iteracion=82, L_tanh=0.33951
# Iteracion=83, L_tanh=0.32445
# Iteracion=84, L_tanh=0.31009
# Iteracion=85, L_tanh=0.29642
# Iteracion=86, L_tanh=0.28343
# Iteracion=87, L_tanh=0.27110
# Iteracion=88, L_tanh=0.25942
# Iteracion=89, L_tanh=0.24836
# Iteracion=90, L_tanh=0.23790
# Iteracion=91, L_tanh=0.22800
# Iteracion=92, L_tanh=0.21865
# Iteracion=93, L_tanh=0.20981
# Iteracion=94, L_tanh=0.20146
# Iteracion=95, L_tanh=0.19357
# Iteracion=96, L_tanh=0.18611
# Iteracion=97, L_tanh=0.17906
# Iteracion=98, L_tanh=0.17240
# Iteracion=99, L_tanh=0.16609
# Iteracion=100, L_tanh=0.16013
# Iteracion=101, L_tanh=0.15448
# Iteracion=102, L_tanh=0.14913
# Iteracion=103, L_tanh=0.14406
# Iteracion=104, L_tanh=0.13926
# Iteracion=105, L_tanh=0.13470
# Iteracion=106, L_tanh=0.13037
# Iteracion=107, L_tanh=0.12625
# Iteracion=108, L_tanh=0.12234
# Iteracion=109, L_tanh=0.11862
# Iteracion=110, L_tanh=0.11508
# Iteracion=111, L_tanh=0.11171
# Iteracion=112, L_tanh=0.10849
# Iteracion=113, L_tanh=0.10543
# Iteracion=114, L_tanh=0.10250
# Iteracion=115, L_tanh=0.09971
# Iteracion=116, L_tanh=0.09704
# Iteracion=117, L_tanh=0.09448
# Iteracion=118, L_tanh=0.09204
# Iteracion=119, L_tanh=0.08970
# Iteracion=120, L_tanh=0.08746
# Iteracion=121, L_tanh=0.08531
# Iteracion=122, L_tanh=0.08325
# Iteracion=123, L_tanh=0.08127
# Iteracion=124, L_tanh=0.07937
# Iteracion=125, L_tanh=0.07755
# Iteracion=126, L_tanh=0.07579
# Iteracion=127, L_tanh=0.07411
# Iteracion=128, L_tanh=0.07248
# Iteracion=129, L_tanh=0.07092
# Iteracion=130, L_tanh=0.06941
# Iteracion=131, L_tanh=0.06796
# Iteracion=132, L_tanh=0.06656
# Iteracion=133, L_tanh=0.06521
# Iteracion=134, L_tanh=0.06391
# Iteracion=135, L_tanh=0.06265
# Iteracion=136, L_tanh=0.06144
# Iteracion=137, L_tanh=0.06026
# Iteracion=138, L_tanh=0.05912
# Iteracion=139, L_tanh=0.05802
# Iteracion=140, L_tanh=0.05696
# Iteracion=141, L_tanh=0.05593
# Iteracion=142, L_tanh=0.05493
# Iteracion=143, L_tanh=0.05397
# Iteracion=144, L_tanh=0.05303
# Iteracion=145, L_tanh=0.05212
# Iteracion=146, L_tanh=0.05124
# Iteracion=147, L_tanh=0.05038
# Iteracion=148, L_tanh=0.04955
# Iteracion=149, L_tanh=0.04875
# Iteracion=150, L_tanh=0.04796
# Iteracion=151, L_tanh=0.04720
# Iteracion=152, L_tanh=0.04646
# Iteracion=153, L_tanh=0.04575
# Iteracion=154, L_tanh=0.04505
# Iteracion=155, L_tanh=0.04437
# Iteracion=156, L_tanh=0.04370
# Iteracion=157, L_tanh=0.04306
# Iteracion=158, L_tanh=0.04243
# Iteracion=159, L_tanh=0.04182
# Iteracion=160, L_tanh=0.04122
# Iteracion=161, L_tanh=0.04064
# Iteracion=162, L_tanh=0.04008
# Iteracion=163, L_tanh=0.03952
# Iteracion=164, L_tanh=0.03899
# Iteracion=165, L_tanh=0.03846
# Iteracion=166, L_tanh=0.03795
# Iteracion=167, L_tanh=0.03745
# Iteracion=168, L_tanh=0.03696
# Iteracion=169, L_tanh=0.03648
# Iteracion=170, L_tanh=0.03602
# Iteracion=171, L_tanh=0.03556
# Iteracion=172, L_tanh=0.03511
# Iteracion=173, L_tanh=0.03468
# Iteracion=174, L_tanh=0.03425
# Iteracion=175, L_tanh=0.03384
# Iteracion=176, L_tanh=0.03343
# Iteracion=177, L_tanh=0.03303
# Iteracion=178, L_tanh=0.03264
# Iteracion=179, L_tanh=0.03226
# Iteracion=180, L_tanh=0.03189
# Iteracion=181, L_tanh=0.03152
# Iteracion=182, L_tanh=0.03117
# Iteracion=183, L_tanh=0.03082
# Iteracion=184, L_tanh=0.03047
# Iteracion=185, L_tanh=0.03014
# Iteracion=186, L_tanh=0.02981
# Iteracion=187, L_tanh=0.02949
# Iteracion=188, L_tanh=0.02917
# Iteracion=189, L_tanh=0.02886
# Iteracion=190, L_tanh=0.02855
# Iteracion=191, L_tanh=0.02826
# Iteracion=192, L_tanh=0.02796
# Iteracion=193, L_tanh=0.02768
# Iteracion=194, L_tanh=0.02739
# Iteracion=195, L_tanh=0.02712
# Iteracion=196, L_tanh=0.02685
# Iteracion=197, L_tanh=0.02658
# Iteracion=198, L_tanh=0.02632
# Iteracion=199, L_tanh=0.02606
# Iteracion=200, L_tanh=0.02581
# Iteracion=201, L_tanh=0.02556
# Iteracion=202, L_tanh=0.02532
# Iteracion=203, L_tanh=0.02508
# Iteracion=204, L_tanh=0.02484
# Iteracion=205, L_tanh=0.02461
# Iteracion=206, L_tanh=0.02438
# Iteracion=207, L_tanh=0.02416
# Iteracion=208, L_tanh=0.02394
# Iteracion=209, L_tanh=0.02372
# Iteracion=210, L_tanh=0.02351
# Iteracion=211, L_tanh=0.02330
# Iteracion=212, L_tanh=0.02310
# Iteracion=213, L_tanh=0.02290
# Iteracion=214, L_tanh=0.02270
# Iteracion=215, L_tanh=0.02250
# Iteracion=216, L_tanh=0.02231
# Iteracion=217, L_tanh=0.02212
# Iteracion=218, L_tanh=0.02193
# Iteracion=219, L_tanh=0.02175
# Iteracion=220, L_tanh=0.02157
# Iteracion=221, L_tanh=0.02139
# Iteracion=222, L_tanh=0.02122
# Iteracion=223, L_tanh=0.02104
# Iteracion=224, L_tanh=0.02087
# Iteracion=225, L_tanh=0.02071
# Iteracion=226, L_tanh=0.02054
# Iteracion=227, L_tanh=0.02038
# Iteracion=228, L_tanh=0.02022
# Iteracion=229, L_tanh=0.02006
# Iteracion=230, L_tanh=0.01990
# Iteracion=231, L_tanh=0.01975
# Iteracion=232, L_tanh=0.01960
# Iteracion=233, L_tanh=0.01945
# Iteracion=234, L_tanh=0.01930
# Iteracion=235, L_tanh=0.01916
# Iteracion=236, L_tanh=0.01902
# Iteracion=237, L_tanh=0.01888
# Iteracion=238, L_tanh=0.01874
# Iteracion=239, L_tanh=0.01860
# Iteracion=240, L_tanh=0.01846
# Iteracion=241, L_tanh=0.01833
# Iteracion=242, L_tanh=0.01820
# Iteracion=243, L_tanh=0.01807
# Iteracion=244, L_tanh=0.01794
# Iteracion=245, L_tanh=0.01782
# Iteracion=246, L_tanh=0.01769
# Iteracion=247, L_tanh=0.01757
# Iteracion=248, L_tanh=0.01745
# Iteracion=249, L_tanh=0.01733
# Iteracion=250, L_tanh=0.01721
# Iteracion=251, L_tanh=0.01709
# Iteracion=252, L_tanh=0.01698
# Iteracion=253, L_tanh=0.01686
# Iteracion=254, L_tanh=0.01675
# Iteracion=255, L_tanh=0.01664
# Iteracion=256, L_tanh=0.01653
# Iteracion=257, L_tanh=0.01642
# Iteracion=258, L_tanh=0.01631
# Iteracion=259, L_tanh=0.01621
# Iteracion=260, L_tanh=0.01610
# Iteracion=261, L_tanh=0.01600
# Iteracion=262, L_tanh=0.01590
# Iteracion=263, L_tanh=0.01580
# Iteracion=264, L_tanh=0.01570
# Iteracion=265, L_tanh=0.01560
# Iteracion=266, L_tanh=0.01550
# Iteracion=267, L_tanh=0.01541
# Iteracion=268, L_tanh=0.01531
# Iteracion=269, L_tanh=0.01522
# Iteracion=270, L_tanh=0.01512
# Iteracion=271, L_tanh=0.01503
# Iteracion=272, L_tanh=0.01494
# Iteracion=273, L_tanh=0.01485
# Iteracion=274, L_tanh=0.01476
# Iteracion=275, L_tanh=0.01468
# Iteracion=276, L_tanh=0.01459
# Iteracion=277, L_tanh=0.01450
# Iteracion=278, L_tanh=0.01442
# Iteracion=279, L_tanh=0.01433
# Iteracion=280, L_tanh=0.01425
# Iteracion=281, L_tanh=0.01417
# Iteracion=282, L_tanh=0.01409
# Iteracion=283, L_tanh=0.01401
# Iteracion=284, L_tanh=0.01393
# Iteracion=285, L_tanh=0.01385
# Iteracion=286, L_tanh=0.01377
# Iteracion=287, L_tanh=0.01370
# Iteracion=288, L_tanh=0.01362
# Iteracion=289, L_tanh=0.01354
# Iteracion=290, L_tanh=0.01347
# Iteracion=291, L_tanh=0.01340
# Iteracion=292, L_tanh=0.01332
# Iteracion=293, L_tanh=0.01325
# Iteracion=294, L_tanh=0.01318
# Iteracion=295, L_tanh=0.01311
# Iteracion=296, L_tanh=0.01304
# Iteracion=297, L_tanh=0.01297
# Iteracion=298, L_tanh=0.01290
# Iteracion=299, L_tanh=0.01283
# Iteracion=300, L_tanh=0.01276
# Iteracion=301, L_tanh=0.01270
# Iteracion=302, L_tanh=0.01263
# Iteracion=303, L_tanh=0.01257
# Iteracion=304, L_tanh=0.01250
# Iteracion=305, L_tanh=0.01244
# Iteracion=306, L_tanh=0.01237
# Iteracion=307, L_tanh=0.01231
# Iteracion=308, L_tanh=0.01225
# Iteracion=309, L_tanh=0.01219
# Iteracion=310, L_tanh=0.01213
# Iteracion=311, L_tanh=0.01207
# Iteracion=312, L_tanh=0.01201
# Iteracion=313, L_tanh=0.01195
# Iteracion=314, L_tanh=0.01189
# Iteracion=315, L_tanh=0.01183
# Iteracion=316, L_tanh=0.01177
# Iteracion=317, L_tanh=0.01171
# Iteracion=318, L_tanh=0.01166
# Iteracion=319, L_tanh=0.01160
# Iteracion=320, L_tanh=0.01155
# Iteracion=321, L_tanh=0.01149
# Iteracion=322, L_tanh=0.01144
# Iteracion=323, L_tanh=0.01138
# Iteracion=324, L_tanh=0.01133
# Iteracion=325, L_tanh=0.01128
# Iteracion=326, L_tanh=0.01122
# Iteracion=327, L_tanh=0.01117
# Iteracion=328, L_tanh=0.01112
# Iteracion=329, L_tanh=0.01107
# Iteracion=330, L_tanh=0.01102
# Iteracion=331, L_tanh=0.01097
# Iteracion=332, L_tanh=0.01092
# Iteracion=333, L_tanh=0.01087
# Iteracion=334, L_tanh=0.01082
# Iteracion=335, L_tanh=0.01077
# Iteracion=336, L_tanh=0.01072
# Iteracion=337, L_tanh=0.01067
# Iteracion=338, L_tanh=0.01062
# Iteracion=339, L_tanh=0.01058
# Iteracion=340, L_tanh=0.01053
# Iteracion=341, L_tanh=0.01048
# Iteracion=342, L_tanh=0.01044
# Iteracion=343, L_tanh=0.01039
# Iteracion=344, L_tanh=0.01035
# Iteracion=345, L_tanh=0.01030
# Iteracion=346, L_tanh=0.01026
# Iteracion=347, L_tanh=0.01022
# Iteracion=348, L_tanh=0.01017
# Iteracion=349, L_tanh=0.01013
# Iteracion=350, L_tanh=0.01008
# Iteracion=351, L_tanh=0.01004
# Iteracion=352, L_tanh=0.01000
# Iteracion=353, L_tanh=0.00996
# Iteracion=354, L_tanh=0.00992
# Iteracion=355, L_tanh=0.00988
# Iteracion=356, L_tanh=0.00983
# Iteracion=357, L_tanh=0.00979
# Iteracion=358, L_tanh=0.00975
# Iteracion=359, L_tanh=0.00971
# Iteracion=360, L_tanh=0.00967
# Iteracion=361, L_tanh=0.00963
# Iteracion=362, L_tanh=0.00959
# Iteracion=363, L_tanh=0.00956
# Iteracion=364, L_tanh=0.00952
# Iteracion=365, L_tanh=0.00948
# Iteracion=366, L_tanh=0.00944
# Iteracion=367, L_tanh=0.00940
# Iteracion=368, L_tanh=0.00937
# Iteracion=369, L_tanh=0.00933
# Iteracion=370, L_tanh=0.00929
# Iteracion=371, L_tanh=0.00926
# Iteracion=372, L_tanh=0.00922
# Iteracion=373, L_tanh=0.00918
# Iteracion=374, L_tanh=0.00915
# Iteracion=375, L_tanh=0.00911
# Iteracion=376, L_tanh=0.00908
# Iteracion=377, L_tanh=0.00904
# Iteracion=378, L_tanh=0.00901
# Iteracion=379, L_tanh=0.00897
# Iteracion=380, L_tanh=0.00894
# Iteracion=381, L_tanh=0.00891
# Iteracion=382, L_tanh=0.00887
# Iteracion=383, L_tanh=0.00884
# Iteracion=384, L_tanh=0.00881
# Iteracion=385, L_tanh=0.00877
# Iteracion=386, L_tanh=0.00874
# Iteracion=387, L_tanh=0.00871
# Iteracion=388, L_tanh=0.00868
# Iteracion=389, L_tanh=0.00864
# Iteracion=390, L_tanh=0.00861
# Iteracion=391, L_tanh=0.00858
# Iteracion=392, L_tanh=0.00855
# Iteracion=393, L_tanh=0.00852
# Iteracion=394, L_tanh=0.00849
# Iteracion=395, L_tanh=0.00846
# Iteracion=396, L_tanh=0.00843
# Iteracion=397, L_tanh=0.00840
# Iteracion=398, L_tanh=0.00836
# Iteracion=399, L_tanh=0.00834
# Iteracion=400, L_tanh=0.00831
# Iteracion=401, L_tanh=0.00828
# Iteracion=402, L_tanh=0.00825
# Iteracion=403, L_tanh=0.00822
# Iteracion=404, L_tanh=0.00819
# Iteracion=405, L_tanh=0.00816
# Iteracion=406, L_tanh=0.00813
# Iteracion=407, L_tanh=0.00810
# Iteracion=408, L_tanh=0.00808
# Iteracion=409, L_tanh=0.00805
# Iteracion=410, L_tanh=0.00802
# Iteracion=411, L_tanh=0.00799
# Iteracion=412, L_tanh=0.00796
# Iteracion=413, L_tanh=0.00794
# Iteracion=414, L_tanh=0.00791
# Iteracion=415, L_tanh=0.00788
# Iteracion=416, L_tanh=0.00786
# Iteracion=417, L_tanh=0.00783
# Iteracion=418, L_tanh=0.00780
# Iteracion=419, L_tanh=0.00778
# Iteracion=420, L_tanh=0.00775
# Iteracion=421, L_tanh=0.00773
# Iteracion=422, L_tanh=0.00770
# Iteracion=423, L_tanh=0.00767
# Iteracion=424, L_tanh=0.00765
# Iteracion=425, L_tanh=0.00762
# Iteracion=426, L_tanh=0.00760
# Iteracion=427, L_tanh=0.00757
# Iteracion=428, L_tanh=0.00755
# Iteracion=429, L_tanh=0.00753
# Iteracion=430, L_tanh=0.00750
# Iteracion=431, L_tanh=0.00748
# Iteracion=432, L_tanh=0.00745
# Iteracion=433, L_tanh=0.00743
# Iteracion=434, L_tanh=0.00740
# Iteracion=435, L_tanh=0.00738
# Iteracion=436, L_tanh=0.00736
# Iteracion=437, L_tanh=0.00733
# Iteracion=438, L_tanh=0.00731
# Iteracion=439, L_tanh=0.00729
# Iteracion=440, L_tanh=0.00727
# Iteracion=441, L_tanh=0.00724
# Iteracion=442, L_tanh=0.00722
# Iteracion=443, L_tanh=0.00720
# Iteracion=444, L_tanh=0.00717
# Iteracion=445, L_tanh=0.00715
# Iteracion=446, L_tanh=0.00713
# Iteracion=447, L_tanh=0.00711
# Iteracion=448, L_tanh=0.00709
# Iteracion=449, L_tanh=0.00706
# Iteracion=450, L_tanh=0.00704
# Iteracion=451, L_tanh=0.00702
# Iteracion=452, L_tanh=0.00700
# Iteracion=453, L_tanh=0.00698
# Iteracion=454, L_tanh=0.00696
# Iteracion=455, L_tanh=0.00694
# Iteracion=456, L_tanh=0.00692
# Iteracion=457, L_tanh=0.00690
# Iteracion=458, L_tanh=0.00687
# Iteracion=459, L_tanh=0.00685
# Iteracion=460, L_tanh=0.00683
# Iteracion=461, L_tanh=0.00681
# Iteracion=462, L_tanh=0.00679
# Iteracion=463, L_tanh=0.00677
# Iteracion=464, L_tanh=0.00675
# Iteracion=465, L_tanh=0.00673
# Iteracion=466, L_tanh=0.00671
# Iteracion=467, L_tanh=0.00669
# Iteracion=468, L_tanh=0.00667
# Iteracion=469, L_tanh=0.00666
# Iteracion=470, L_tanh=0.00664
# Iteracion=471, L_tanh=0.00662
# Iteracion=472, L_tanh=0.00660
# Iteracion=473, L_tanh=0.00658
# Iteracion=474, L_tanh=0.00656
# Iteracion=475, L_tanh=0.00654
# Iteracion=476, L_tanh=0.00652
# Iteracion=477, L_tanh=0.00650
# Iteracion=478, L_tanh=0.00649
# Iteracion=479, L_tanh=0.00647
# Iteracion=480, L_tanh=0.00645
# Iteracion=481, L_tanh=0.00643
# Iteracion=482, L_tanh=0.00641
# Iteracion=483, L_tanh=0.00639
# Iteracion=484, L_tanh=0.00638
# Iteracion=485, L_tanh=0.00636
# Iteracion=486, L_tanh=0.00634
# Iteracion=487, L_tanh=0.00632
# Iteracion=488, L_tanh=0.00631
# Iteracion=489, L_tanh=0.00629
# Iteracion=490, L_tanh=0.00627
# Iteracion=491, L_tanh=0.00625
# Iteracion=492, L_tanh=0.00624
# Iteracion=493, L_tanh=0.00622
# Iteracion=494, L_tanh=0.00620
# Iteracion=495, L_tanh=0.00619
# Iteracion=496, L_tanh=0.00617
# Iteracion=497, L_tanh=0.00615
# Iteracion=498, L_tanh=0.00614
# Iteracion=499, L_tanh=0.00612

# %%
# Impresión de resultados

print(f"Valor final L_tanh : {L_tanh.data:.5f}")
print("Predicciones finales:", [y.data for y in yhat])
#show_graph(L_tanh)
# Out:
# Valor final L_tanh : 0.00612
# Predicciones finales: [-0.9119114455678722, 0.9340614798173603, 0.9340555316002931, -0.9104201349714249]
# 'grafo_xor.png'
